# %%
import pymongo
import pandas as pd
from pytz import timezone
from bson.codec_options import CodecOptions
import matplotlib.pyplot as plt
from pymongo import MongoClient
# %matplotlib inline

#global const's
WEEKS = 8
TIMESTAMPS_PER_HOUR = 2
#global var's
local_client = MongoClient('localhost', 27017)
coll = local_client.admin.passwords
doc = coll.find_one({"key":"MONGOMLAB"})
mongopass = doc["value"]
slack_keys = local_client.admin.passwords.find_one({"key":"SLACK_ALEXPLAYGROUND"})["value"]

# %%
client = MongoClient(f"mongodb://nailbiter:{mongopass}@ds149672.mlab.com:49672/logistics")
timecoll = client.logistics["alex.taskLog"].with_options(codec_options=CodecOptions(tz_aware=True,tzinfo=timezone('Asia/Tokyo')))
# Out:
#                         _id                             date     message  \
# 0  5d52c0a654765d6c28397f28 2019-08-13 22:52:37.853000+09:00  add engage
# 1  5d52c37340333b4104104f50 2019-08-13 23:04:35.525000+09:00  add engage
# 2  5d53769a40333b4104104f82 2019-08-14 11:48:58.852000+09:00  add engage
# 3  5d53ab2640333b4104104f91 2019-08-14 15:33:10.793000+09:00  add engage
# 4  5d54cf3c40333b4104104feb 2019-08-15 12:19:24.788000+09:00  add engage
#
#                                                  obj
# 0  {'pos': 22790143, 'due': None, 'shortUrl': 'ht...
# 1  {'pos': 1032192, 'due': None, 'shortUrl': 'htt...
# 2  {'pos': 524320, 'due': None, 'shortUrl': 'http...
# 3  {'pos': 1032192, 'due': None, 'shortUrl': 'htt...
# 4  {'pos': 22790143, 'due': None, 'shortUrl': 'ht...

# %%
import pandas as pd

docs = list(timecoll.find({"message":"add engage"}))
money_df = pd.DataFrame(docs)
money_df.head()
_df = pd.DataFrame([{"date":r["date"],**r["obj"]} for r in money_df.to_dict(orient="records")])
_df = _df[["2020-08-06"<=x.strftime("%Y-%m-%d")<="2020-08-07" for x in _df["date"]]].set_index("date").sort_index()
_df
# Out:
#                                         pos   due  \
# date
# 2020-08-06 10:14:47.333000+09:00  1409024.0  None
# 2020-08-06 19:05:04.834000+09:00  7012352.0  None
# 2020-08-07 15:00:49.125000+09:00  7028736.0  None
# 2020-08-07 15:39:37.078000+09:00  1409024.0  None
# 2020-08-07 16:31:20.303000+09:00  7127040.0  None
# 2020-08-07 17:00:47.170000+09:00  2523136.0  None
# 2020-08-07 17:29:53.026000+09:00  2359296.0  None
# 2020-08-07 18:29:17.852000+09:00  1409024.0  None
# 2020-08-07 21:55:23.422000+09:00  7012352.0  None
#
#                                                        shortUrl  \
# date
# 2020-08-06 10:14:47.333000+09:00  https://trello.com/c/manaPrbs
# 2020-08-06 19:05:04.834000+09:00  https://trello.com/c/Ar9urybZ
# 2020-08-07 15:00:49.125000+09:00  https://trello.com/c/8xBhbrKS
# 2020-08-07 15:39:37.078000+09:00  https://trello.com/c/manaPrbs
# 2020-08-07 16:31:20.303000+09:00  https://trello.com/c/acdYlx5c
# ...
