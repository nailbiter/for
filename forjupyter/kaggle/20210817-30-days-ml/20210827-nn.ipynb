# %%
# %load_ext autoreload
# %autoreload 1

# %%
# Familiar imports
import numpy as np
import pandas as pd

# For ordinal encoding categorical variables, splitting data
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split, cross_val_score

# For training random forest model
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

import os
from os import path
import random
# import zipfile
import tqdm
# %aimport common
# %aimport common_scoring
# %aimport common_prediction
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost
from datetime import datetime
import itertools
import json
import functools
from sklearn.feature_selection import mutual_info_regression
import logging
import matplotlib.pyplot as plt

from sklearn.compose import ColumnTransformer
from sklearn.datasets import fetch_openml
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, GridSearchCV

import webbrowser

FN = path.join(os.getcwd(),"20210827-nn")

# %%
X,y,X_test = common.setup()
X_train, X_valid, y_train, y_valid = train_test_split(X, y, random_state=0)

SUBMISSION_DATE=datetime(2021,8,26)

# %%
logging.warning({k:v.nunique() for k,v in X.items() if k.startswith("cat")})
# Out:
# WARNING:root:{'cat0': 2, 'cat1': 2, 'cat2': 2, 'cat3': 4, 'cat4': 4, 'cat5': 4, 'cat6': 8, 'cat7': 8, 'cat8': 7, 'cat9': 15}

# %%
small_card_cats = [cn for cn,s in X.items() if cn.startswith("cat") and s.nunique()<=4]
num_cats = [cn for cn in X if cn.startswith("cont")]
big_card_cats = [cn for cn in X if cn not in small_card_cats and cn.startswith("cat")]

# small_card_cats
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_transformer = OneHotEncoder(handle_unknown='ignore')

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, num_cats),
        ('cat', categorical_transformer, small_card_cats),
        ('drop', "drop", big_card_cats),
    ]
)

# %%
transformed_colnames = [cn for cn in X if cn.startswith("cont")]+list(itertools.chain(*[[f"{cn}_{i}" for i in range(X[cn].nunique())] for cn in small_card_cats]))
X_train_processed = pd.DataFrame(data=preprocessor.fit_transform(X_train),columns=transformed_colnames)
X_valid_processed = pd.DataFrame(data=preprocessor.transform(X_valid),columns=transformed_colnames)

# %%
from tensorflow import keras
from tensorflow.keras import layers
def build_model():
    model = keras.Sequential([
        layers.BatchNormalization(),
        layers.Dense(512, activation='relu', input_shape=[X_train_processed.shape[1]]),
        layers.Dropout(rate=0.3),
        layers.BatchNormalization(),
        layers.Dense(512, activation='relu'),
        layers.Dropout(rate=0.3),
        layers.BatchNormalization(),
        layers.Dense(512, activation='relu'),
        layers.Dropout(rate=0.3),
        layers.BatchNormalization(),
        layers.Dense(1),
    ])
    model.compile(
        optimizer='adam',
        loss='mae',
    )
    return model
model = build_model()

# %%
# %%time
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

history = model.fit(
    X_train_processed, y_train,
    validation_data=(X_valid_processed, y_valid),
    batch_size=256,
#     epochs=10,
    epochs=100,
    callbacks=[early_stopping], 
    verbose=0,
)

# _,ax = plt.subplots(figsize=(20,10))
# pd.DataFrame(history.history).plot(ax=ax)

np.sqrt(mean_squared_error(model.predict(X_valid_processed),y_valid))
# Out:
# CPU times: user 26min 49s, sys: 10min 10s, total: 36min 59s
# Wall time: 9min 18s
# 0.7429681170990439

# %%
_,ax = plt.subplots(figsize=(20,10))
pd.DataFrame(history.history)[5:].plot(ax=ax)
# Out:
# <AxesSubplot:>

# %%
common.call_me("nn done")

# %%
0.7432137035971532
# Out:
# 0.7432137035971532

# %%
# %time
from keras.wrappers.scikit_learn import KerasRegressor

print(datetime.now().isoformat())
sk_params = dict(
#         validation_data=(X_valid_processed, y_valid),
    batch_size=256,
#     epochs=10,
    epochs=100,
#     callbacks=[early_stopping], 
#     verbose=0,
)
common.score_dataset(X,y,
                     model=Pipeline(steps=[
                         ("preprocessor",preprocessor),
                         ("predictor",KerasRegressor(build_fn=build_model,**sk_params))
                     ]), 
                    )
# Out:
# CPU times: user 2 µs, sys: 2 µs, total: 4 µs
# Wall time: 7.87 µs
# 2021-08-29T22:05:24.668587
# Epoch 1/100
# 938/938 [==============================] - 13s 13ms/step - loss: 1.3474
# Epoch 2/100
# 938/938 [==============================] - 18s 19ms/step - loss: 0.7114
# Epoch 3/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.6739
# Epoch 4/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6513
# Epoch 5/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.6371
# Epoch 6/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.6281
# Epoch 7/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.6197 0s - loss: 0
# Epoch 8/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.6158
# Epoch 9/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6105
# Epoch 10/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6079
# Epoch 11/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.6043
# Epoch 12/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6020
# Epoch 13/100
# 938/938 [==============================] - 17s 19ms/step - loss: 0.5998
# Epoch 14/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5979
# Epoch 15/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5965
# Epoch 16/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5952
# Epoch 17/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5936
# Epoch 18/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5926
# Epoch 19/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5924
# Epoch 20/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5905
# Epoch 21/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5897
# Epoch 22/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5888
# Epoch 23/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5892
# Epoch 24/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5876
# Epoch 25/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5873
# Epoch 26/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5869
# Epoch 27/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5864
# Epoch 28/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5868
# Epoch 29/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5863
# Epoch 30/100
# 938/938 [==============================] - 18s 19ms/step - loss: 0.5859
# Epoch 31/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5855
# Epoch 32/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5855
# Epoch 33/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5846
# Epoch 34/100
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5851
# Epoch 35/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5845
# Epoch 36/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5840
# Epoch 37/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5845
# Epoch 38/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5846
# Epoch 39/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5840
# Epoch 40/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5833
# Epoch 41/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5831
# Epoch 42/100
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5830
# Epoch 43/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5828
# Epoch 44/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5823
# Epoch 45/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5824
# Epoch 46/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5818
# Epoch 47/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5816
# Epoch 48/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5815
# Epoch 49/100
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5811
# Epoch 50/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5805
# Epoch 51/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5803
# Epoch 52/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5802
# Epoch 53/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5795
# Epoch 54/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5796
# Epoch 55/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5793
# Epoch 56/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5788
# Epoch 57/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5781
# Epoch 58/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5781
# Epoch 59/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5779
# Epoch 60/100
# 938/938 [==============================] - 16s 18ms/step - loss: 0.5776
# Epoch 61/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5772
# Epoch 62/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5773
# Epoch 63/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5765
# Epoch 64/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5767
# Epoch 65/100
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5765
# Epoch 66/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5761
# Epoch 67/100
# 938/938 [==============================] - 15s 15ms/step - loss: 0.5760
# Epoch 68/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5756
# Epoch 69/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5751
# Epoch 70/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5748
# Epoch 71/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5747
# Epoch 72/100
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5744
# Epoch 73/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5739
# Epoch 74/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5736
# Epoch 75/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5734
# Epoch 76/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5737
# Epoch 77/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5735
# Epoch 78/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5729
# Epoch 79/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5725
# Epoch 80/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5720
# Epoch 81/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5716
# Epoch 82/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5717
# Epoch 83/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5715
# Epoch 84/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5711
# Epoch 85/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5710
# Epoch 86/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5709
# Epoch 87/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5710
# Epoch 88/100
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5702
# Epoch 89/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5701
# Epoch 90/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5700
# Epoch 91/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5698
# Epoch 92/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5697
# Epoch 93/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5692
# Epoch 94/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5695
# Epoch 95/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5694
# Epoch 96/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5687
# Epoch 97/100
# 938/938 [==============================] - 17s 19ms/step - loss: 0.5689
# Epoch 98/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5684
# Epoch 99/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5681
# Epoch 100/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5684
# Epoch 1/100
# 938/938 [==============================] - 23s 23ms/step - loss: 1.3397
# Epoch 2/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.7054
# Epoch 3/100
# 938/938 [==============================] - 25s 26ms/step - loss: 0.6710
# Epoch 4/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.6486
# Epoch 5/100
# 938/938 [==============================] - 25s 26ms/step - loss: 0.6360
# Epoch 6/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.6269
# Epoch 7/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.6185
# Epoch 8/100
# 938/938 [==============================] - 23s 24ms/step - loss: 0.6134
# Epoch 9/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.6098
# Epoch 10/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.6075
# Epoch 11/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.6035
# Epoch 12/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.6019
# Epoch 13/100
# 938/938 [==============================] - 23s 24ms/step - loss: 0.5993
# Epoch 14/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5974
# Epoch 15/100
# 938/938 [==============================] - 20s 21ms/step - loss: 0.5948
# Epoch 16/100
# 938/938 [==============================] - 18s 19ms/step - loss: 0.5939
# Epoch 17/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5916
# Epoch 18/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5908
# Epoch 19/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5894
# Epoch 20/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5887
# Epoch 21/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5887
# Epoch 22/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5874
# Epoch 23/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5871
# Epoch 24/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5858
# Epoch 25/100
# 938/938 [==============================] - 20s 21ms/step - loss: 0.5853
# Epoch 26/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5853
# Epoch 27/100
# 938/938 [==============================] - 18s 19ms/step - loss: 0.5847
# Epoch 28/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5842
# Epoch 29/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5841
# Epoch 30/100
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5844
# Epoch 31/100
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5830
# Epoch 32/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5832
# Epoch 33/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5835
# Epoch 34/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5823
# Epoch 35/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5827
# Epoch 36/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5820
# Epoch 37/100
# 938/938 [==============================] - 20s 22ms/step - loss: 0.5822
# Epoch 38/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.5816
# Epoch 39/100
# 938/938 [==============================] - 26s 28ms/step - loss: 0.5808
# Epoch 40/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.5810
# Epoch 41/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.5801
# Epoch 42/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.5799
# Epoch 43/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.5802
# Epoch 44/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.5794
# Epoch 45/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.5788
# Epoch 46/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.5788
# Epoch 47/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.5783
# Epoch 48/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.5782
# Epoch 49/100
# 938/938 [==============================] - 25s 26ms/step - loss: 0.5778
# Epoch 50/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.5773
# Epoch 51/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.5771
# Epoch 52/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.5769
# Epoch 53/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.5769
# Epoch 54/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5760
# Epoch 55/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5759
# Epoch 56/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5753
# Epoch 57/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5752
# Epoch 58/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5749
# Epoch 59/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5749
# Epoch 60/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5746
# Epoch 61/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5742
# Epoch 62/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5733
# Epoch 63/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5732
# Epoch 64/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5733
# Epoch 65/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5728
# Epoch 66/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5725
# Epoch 67/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5724
# Epoch 68/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5722
# Epoch 69/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5720
# Epoch 70/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5718
# Epoch 71/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5715
# Epoch 72/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5711
# Epoch 73/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5709
# Epoch 74/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5707
# Epoch 75/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5704
# Epoch 76/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5703
# Epoch 77/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5700
# Epoch 78/100
# 938/938 [==============================] - 15s 15ms/step - loss: 0.5696
# Epoch 79/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5695
# Epoch 80/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5694
# Epoch 81/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5693
# Epoch 82/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5691
# Epoch 83/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5689
# Epoch 84/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5687
# Epoch 85/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5685
# Epoch 86/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5676
# Epoch 87/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5678
# Epoch 88/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5675
# Epoch 89/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5676
# Epoch 90/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5675
# Epoch 91/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5670
# Epoch 92/100
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5673
# Epoch 93/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5668
# Epoch 94/100
# 938/938 [==============================] - 15s 17ms/step - loss: 0.5663
# Epoch 95/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5661
# Epoch 96/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5662
# Epoch 97/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5653
# Epoch 98/100
# 938/938 [==============================] - 15s 15ms/step - loss: 0.5654
# Epoch 99/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5655
# Epoch 100/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5646
# Epoch 1/100
# 938/938 [==============================] - 15s 15ms/step - loss: 1.3330
# Epoch 2/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.7100
# Epoch 3/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6723
# Epoch 4/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6491
# Epoch 5/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6354
# Epoch 6/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.6268
# Epoch 7/100
# 938/938 [==============================] - 15s 15ms/step - loss: 0.6192
# Epoch 8/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6144
# Epoch 9/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6100
# Epoch 10/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6065
# Epoch 11/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.6035
# Epoch 12/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6013
# Epoch 13/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5996
# Epoch 14/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5975
# Epoch 15/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5954
# Epoch 16/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5938
# Epoch 17/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5921
# Epoch 18/100
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5910
# Epoch 19/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5905
# Epoch 20/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5888
# Epoch 21/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5887
# Epoch 22/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5871
# Epoch 23/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5862
# Epoch 24/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5867
# Epoch 25/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5858
# Epoch 26/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5853
# Epoch 27/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5852
# Epoch 28/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5851
# Epoch 29/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5842
# Epoch 30/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5845
# Epoch 31/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5846
# Epoch 32/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5834
# Epoch 33/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5836
# Epoch 34/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5838
# Epoch 35/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5829
# Epoch 36/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5831
# Epoch 37/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5821
# Epoch 38/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5822
# Epoch 39/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5822
# Epoch 40/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5824
# Epoch 41/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5809
# Epoch 42/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5808
# Epoch 43/100
# 938/938 [==============================] - 15s 15ms/step - loss: 0.5806
# Epoch 44/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5803
# Epoch 45/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5797
# Epoch 46/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5794
# Epoch 47/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5794
# Epoch 48/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5785
# Epoch 49/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5784
# Epoch 50/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5779
# Epoch 51/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5775
# Epoch 52/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5776
# Epoch 53/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5772
# Epoch 54/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5769
# Epoch 55/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5768
# Epoch 56/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5763
# Epoch 57/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5755
# Epoch 58/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5758
# Epoch 59/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5750
# Epoch 60/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5749
# Epoch 61/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5746
# Epoch 62/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5745
# Epoch 63/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5742
# Epoch 64/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5741
# Epoch 65/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5738
# Epoch 66/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5735
# Epoch 67/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5733
# Epoch 68/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5729
# Epoch 69/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5723
# Epoch 70/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5723
# Epoch 71/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5721
# Epoch 72/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5720
# Epoch 73/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5721
# Epoch 74/100
# 938/938 [==============================] - 15s 15ms/step - loss: 0.5705
# Epoch 75/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5711
# Epoch 76/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5712
# Epoch 77/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5707
# Epoch 78/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5706
# Epoch 79/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5698
# Epoch 80/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5703
# Epoch 81/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5693
# Epoch 82/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5693
# Epoch 83/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5689
# Epoch 84/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5691
# Epoch 85/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5683
# Epoch 86/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5685
# Epoch 87/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5691
# Epoch 88/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5684
# Epoch 89/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5674
# Epoch 90/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5673
# Epoch 91/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5673
# Epoch 92/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5672
# Epoch 93/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5666
# Epoch 94/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5673
# Epoch 95/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5668
# Epoch 96/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5663
# Epoch 97/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5659
# Epoch 98/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5657
# Epoch 99/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5657
# Epoch 100/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5657
# Epoch 1/100
# 938/938 [==============================] - 16s 15ms/step - loss: 1.3336
# Epoch 2/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.7109
# Epoch 3/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.6721
# Epoch 4/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.6499
# Epoch 5/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6364
# Epoch 6/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6261
# Epoch 7/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6188
# Epoch 8/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6143
# Epoch 9/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.6096
# Epoch 10/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6062
# Epoch 11/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6033
# Epoch 12/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.6011
# Epoch 13/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6000
# Epoch 14/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5969
# Epoch 15/100
# 938/938 [==============================] - 15s 15ms/step - loss: 0.5952
# Epoch 16/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5947
# Epoch 17/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5927
# Epoch 18/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5919
# Epoch 19/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5905
# Epoch 20/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5897
# Epoch 21/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5892
# Epoch 22/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5882
# Epoch 23/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5875
# Epoch 24/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5876
# Epoch 25/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5868
# Epoch 26/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5864
# Epoch 27/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5864
# Epoch 28/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5857
# Epoch 29/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5857
# Epoch 30/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5854
# Epoch 31/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5856
# Epoch 32/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5847
# Epoch 33/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5845
# Epoch 34/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5847
# Epoch 35/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5847
# Epoch 36/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5836
# Epoch 37/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5835
# Epoch 38/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5834
# Epoch 39/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5836
# Epoch 40/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5830
# Epoch 41/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5829
# Epoch 42/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5829
# Epoch 43/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5826
# Epoch 44/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5818
# Epoch 45/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5824
# Epoch 46/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5822
# Epoch 47/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5815
# Epoch 48/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5810
# Epoch 49/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5809
# Epoch 50/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5807
# Epoch 51/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5801
# Epoch 52/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5802
# Epoch 53/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5805
# Epoch 54/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5801
# Epoch 55/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5796
# Epoch 56/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5793
# Epoch 57/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5789
# Epoch 58/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5787
# Epoch 59/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5785
# Epoch 60/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5782
# Epoch 61/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5778
# Epoch 62/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5774
# Epoch 63/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5770
# Epoch 64/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5768
# Epoch 65/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5766
# Epoch 66/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5760
# Epoch 67/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5760
# Epoch 68/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5753
# Epoch 69/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5757
# Epoch 70/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5753
# Epoch 71/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5747
# Epoch 72/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5754
# Epoch 73/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5745
# Epoch 74/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5742
# Epoch 75/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5741
# Epoch 76/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5745
# Epoch 77/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5735
# Epoch 78/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5740
# Epoch 79/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5734
# Epoch 80/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5732
# Epoch 81/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5730
# Epoch 82/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5723
# Epoch 83/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5729
# Epoch 84/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5724
# Epoch 85/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5721
# Epoch 86/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5718
# Epoch 87/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5715
# Epoch 88/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5711
# Epoch 89/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5710
# Epoch 90/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5709
# Epoch 91/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5706
# Epoch 92/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5703
# Epoch 93/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5700
# Epoch 94/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5701
# Epoch 95/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5704
# Epoch 96/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5692
# Epoch 97/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5690
# Epoch 98/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5696
# Epoch 99/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5684
# Epoch 100/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5683
# Epoch 1/100
# 938/938 [==============================] - 14s 14ms/step - loss: 1.3472
# Epoch 2/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.7132
# Epoch 3/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.6704
# Epoch 4/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.6488
# Epoch 5/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6381
# Epoch 6/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6270
# Epoch 7/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.6196
# Epoch 8/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.6152
# Epoch 9/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.6103
# Epoch 10/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.6051
# Epoch 11/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6037
# Epoch 12/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.6008
# Epoch 13/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5986
# Epoch 14/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5969
# Epoch 15/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5950
# Epoch 16/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5936
# Epoch 17/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5923
# Epoch 18/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5912
# Epoch 19/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5904
# Epoch 20/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5900
# Epoch 21/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5881
# Epoch 22/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5879
# Epoch 23/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5869
# Epoch 24/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5863
# Epoch 25/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5863
# Epoch 26/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5855
# Epoch 27/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5851
# Epoch 28/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5854
# Epoch 29/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5850
# Epoch 30/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5847
# Epoch 31/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5842
# Epoch 32/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5842
# Epoch 33/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5841
# Epoch 34/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5835
# Epoch 35/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5834
# Epoch 36/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5830
# Epoch 37/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5832
# Epoch 38/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5829
# Epoch 39/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5820
# Epoch 40/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5824
# Epoch 41/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5818
# Epoch 42/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5815
# Epoch 43/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5819
# Epoch 44/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5811
# Epoch 45/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5805
# Epoch 46/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5800
# Epoch 47/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5800
# Epoch 48/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5799
# Epoch 49/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5798
# Epoch 50/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5795
# Epoch 51/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5790
# Epoch 52/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5785
# Epoch 53/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5786
# Epoch 54/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5788
# Epoch 55/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5776
# Epoch 56/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5779
# Epoch 57/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5775
# Epoch 58/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5766
# Epoch 59/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5774
# Epoch 60/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5765
# Epoch 61/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5765
# Epoch 62/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5759
# Epoch 63/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5760
# Epoch 64/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5755
# Epoch 65/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5751
# Epoch 66/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5750
# Epoch 67/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5746
# Epoch 68/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5743
# Epoch 69/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5745
# Epoch 70/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5738
# Epoch 71/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5735
# Epoch 72/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5736
# Epoch 73/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5738
# Epoch 74/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5729
# Epoch 75/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5727
# Epoch 76/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5732
# Epoch 77/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5726
# Epoch 78/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5724
# Epoch 79/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5719
# Epoch 80/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5714
# Epoch 81/100
# 938/938 [==============================] - 13s 14ms/step - loss: 0.5713
# Epoch 82/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5712
# Epoch 83/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5711
# Epoch 84/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5707
# Epoch 85/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5702
# Epoch 86/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5703
# Epoch 87/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5702
# Epoch 88/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5699
# Epoch 89/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5697
# Epoch 90/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5696
# Epoch 91/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5698
# Epoch 92/100
# 938/938 [==============================] - 20s 22ms/step - loss: 0.5687
# Epoch 93/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5686
# Epoch 94/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5682
# Epoch 95/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5682
# Epoch 96/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5686
# Epoch 97/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5683
# Epoch 98/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.5675
# Epoch 99/100
# 938/938 [==============================] - 14s 14ms/step - loss: 0.5677
# Epoch 100/100
# 938/938 [==============================] - 14s 15ms/step - loss: 0.5675
# 0.7520290517541127

# %%
common.call_me("done nn cross-val")

# %%
datetime.now().isoformat()

# %% [markdown]
# ## refs
# 1. https://nobunaga.hatenablog.jp/entry/2017/10/17/071849
# 1. https://faroit.com/keras-docs/2.0.0/scikit-learn-api/
