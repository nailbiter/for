# %%
# %load_ext autoreload
# %autoreload 1

# %%
# Familiar imports
import numpy as np
import pandas as pd

# For ordinal encoding categorical variables, splitting data
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split, cross_val_score

# For training random forest model
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

import os
from os import path
import random
# import zipfile
import tqdm
# %aimport common
# %aimport common_scoring
# %aimport common_prediction
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost
from datetime import datetime
import itertools
import json
import functools
from sklearn.feature_selection import mutual_info_regression
import logging
import matplotlib.pyplot as plt

from sklearn.compose import ColumnTransformer
from sklearn.datasets import fetch_openml
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, GridSearchCV

import webbrowser

FN = path.join(os.getcwd(),"20210927-nn")

# %%
X,y,X_test = common.setup()
X_train, X_valid, y_train, y_valid = train_test_split(X, y, random_state=0)

SUBMISSION_DATE=datetime(2021,8,26)

# %%
from tensorflow import keras
from tensorflow.keras import layers
def build_model():
    model = keras.Sequential([
        layers.BatchNormalization(),
        layers.Dense(512, activation='relu', input_shape=[X_train.shape[1]]),
        layers.Dropout(rate=0.3),
        layers.BatchNormalization(),
        layers.Dense(512, activation='relu'),
        layers.Dropout(rate=0.3),
        layers.BatchNormalization(),
        layers.Dense(512, activation='relu'),
        layers.Dropout(rate=0.3),
        layers.BatchNormalization(),
        layers.Dense(1,activation="sigmoid"),
    ])
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=["accuracy"]
    )
    return model
model = build_model()

# %%
# %%time
# from keras.wrappers.scikit_learn import KerasRegressor
import sklearn.preprocessing, sklearn.impute, sklearn.cluster

print(datetime.now().isoformat())
sk_params = dict(
#         validation_data=(X_valid_processed, y_valid),
    batch_size=256,
#     epochs=10,
    epochs=100,
#     callbacks=[early_stopping], 
#     verbose=0,
)
common.score_dataset(X.values,y.values,
                     model=Pipeline(steps=[
                         ("impute",sklearn.impute.SimpleImputer(strategy="most_frequent")),
                         ("scale",sklearn.preprocessing.StandardScaler()),
                         ("predictor",keras.wrappers.scikit_learn.KerasClassifier(build_fn=build_model,**sk_params))
                     ]), 
                     baseline=0.8050963860090621,
                    )
# Out:
# 2021-09-27T23:11:55.826513
# Epoch 1/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6973 - accuracy: 0.5308
# Epoch 2/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6891 - accuracy: 0.5399
# Epoch 3/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6876 - accuracy: 0.5449
# Epoch 4/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6861 - accuracy: 0.5503
# Epoch 5/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6847 - accuracy: 0.5545
# Epoch 6/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6833 - accuracy: 0.5583
# Epoch 7/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6819 - accuracy: 0.5624
# Epoch 8/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6804 - accuracy: 0.5652
# Epoch 9/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6791 - accuracy: 0.5681
# Epoch 10/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6776 - accuracy: 0.5708
# Epoch 11/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6762 - accuracy: 0.5743
# Epoch 12/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6748 - accuracy: 0.5764
# Epoch 13/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6733 - accuracy: 0.5793
# Epoch 14/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6723 - accuracy: 0.5815
# Epoch 15/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6708 - accuracy: 0.5841
# Epoch 16/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6694 - accuracy: 0.5867
# Epoch 17/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6684 - accuracy: 0.5873
# Epoch 18/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6670 - accuracy: 0.5901
# Epoch 19/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6659 - accuracy: 0.5923
# Epoch 20/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6651 - accuracy: 0.5933
# Epoch 21/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6640 - accuracy: 0.5950
# Epoch 22/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6631 - accuracy: 0.5968
# Epoch 23/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6619 - accuracy: 0.5985
# Epoch 24/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6611 - accuracy: 0.6003
# Epoch 25/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6601 - accuracy: 0.6015
# Epoch 26/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6594 - accuracy: 0.6028
# Epoch 27/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6585 - accuracy: 0.6049
# Epoch 28/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6578 - accuracy: 0.6050
# Epoch 29/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6568 - accuracy: 0.6071
# Epoch 30/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6564 - accuracy: 0.6075
# Epoch 31/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6559 - accuracy: 0.6083
# Epoch 32/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6551 - accuracy: 0.6092
# Epoch 33/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6540 - accuracy: 0.6108
# Epoch 34/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6534 - accuracy: 0.6120
# Epoch 35/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6533 - accuracy: 0.6124
# Epoch 36/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6523 - accuracy: 0.6137
# Epoch 37/100
# 2994/2994 [==============================] - 36s 12ms/step - loss: 0.6519 - accuracy: 0.6147
# Epoch 38/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6512 - accuracy: 0.6153
# Epoch 39/100
# 2994/2994 [==============================] - 36s 12ms/step - loss: 0.6506 - accuracy: 0.6165
# Epoch 40/100
# 2994/2994 [==============================] - 43s 14ms/step - loss: 0.6498 - accuracy: 0.6172
# Epoch 41/100
# 2994/2994 [==============================] - 41s 14ms/step - loss: 0.6494 - accuracy: 0.6185
# Epoch 42/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6490 - accuracy: 0.6181
# Epoch 43/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6483 - accuracy: 0.6193
# Epoch 44/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6482 - accuracy: 0.6204
# Epoch 45/100
# 2994/2994 [==============================] - 42s 14ms/step - loss: 0.6475 - accuracy: 0.6203
# Epoch 46/100
# 2994/2994 [==============================] - 43s 14ms/step - loss: 0.6468 - accuracy: 0.6219
# Epoch 47/100
# 2994/2994 [==============================] - 42s 14ms/step - loss: 0.6463 - accuracy: 0.6217
# Epoch 48/100
# 2994/2994 [==============================] - 42s 14ms/step - loss: 0.6460 - accuracy: 0.6229
# Epoch 49/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6454 - accuracy: 0.6237
# Epoch 50/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6449 - accuracy: 0.6242
# Epoch 51/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6445 - accuracy: 0.6247
# Epoch 52/100
# 2994/2994 [==============================] - 51s 17ms/step - loss: 0.6440 - accuracy: 0.6257
# Epoch 53/100
# 2994/2994 [==============================] - 43s 14ms/step - loss: 0.6433 - accuracy: 0.6270
# Epoch 54/100
# 2994/2994 [==============================] - 43s 14ms/step - loss: 0.6437 - accuracy: 0.6263
# Epoch 55/100
# 2994/2994 [==============================] - 41s 14ms/step - loss: 0.6431 - accuracy: 0.6265
# Epoch 56/100
# 2994/2994 [==============================] - 41s 14ms/step - loss: 0.6419 - accuracy: 0.6285
# Epoch 57/100
# 2994/2994 [==============================] - 41s 14ms/step - loss: 0.6423 - accuracy: 0.6285
# Epoch 58/100
# 2994/2994 [==============================] - 41s 14ms/step - loss: 0.6414 - accuracy: 0.6291
# Epoch 59/100
# 2994/2994 [==============================] - 41s 14ms/step - loss: 0.6413 - accuracy: 0.6297
# Epoch 60/100
# 2994/2994 [==============================] - 41s 14ms/step - loss: 0.6407 - accuracy: 0.6301
# Epoch 61/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6402 - accuracy: 0.6303
# Epoch 62/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6398 - accuracy: 0.6316
# Epoch 63/100
# 2994/2994 [==============================] - 41s 14ms/step - loss: 0.6395 - accuracy: 0.6315
# Epoch 64/100
# 2994/2994 [==============================] - 42s 14ms/step - loss: 0.6395 - accuracy: 0.6314
# Epoch 65/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6387 - accuracy: 0.6324
# Epoch 66/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6383 - accuracy: 0.6333
# Epoch 67/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6384 - accuracy: 0.6336
# Epoch 68/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6381 - accuracy: 0.6332
# Epoch 69/100
# 2994/2994 [==============================] - 41s 14ms/step - loss: 0.6378 - accuracy: 0.6338
# Epoch 70/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6371 - accuracy: 0.6343
# Epoch 71/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6369 - accuracy: 0.6348
# Epoch 72/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6374 - accuracy: 0.6339
# Epoch 73/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6365 - accuracy: 0.6354
# Epoch 74/100
# 2994/2994 [==============================] - 44s 15ms/step - loss: 0.6368 - accuracy: 0.6344
# Epoch 75/100
# 2994/2994 [==============================] - 41s 14ms/step - loss: 0.6366 - accuracy: 0.6351
# Epoch 76/100
# 2994/2994 [==============================] - 46s 15ms/step - loss: 0.6353 - accuracy: 0.6365
# Epoch 77/100
# 2994/2994 [==============================] - 42s 14ms/step - loss: 0.6354 - accuracy: 0.6363
# Epoch 78/100
# 2994/2994 [==============================] - 42s 14ms/step - loss: 0.6355 - accuracy: 0.6369
# Epoch 79/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6345 - accuracy: 0.6376
# Epoch 80/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6346 - accuracy: 0.6373
# Epoch 81/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6345 - accuracy: 0.6373
# Epoch 82/100
# 2994/2994 [==============================] - 41s 14ms/step - loss: 0.6341 - accuracy: 0.6387
# Epoch 83/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6335 - accuracy: 0.6390
# Epoch 84/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6332 - accuracy: 0.6399
# Epoch 85/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6326 - accuracy: 0.6403
# Epoch 86/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6325 - accuracy: 0.6400
# Epoch 87/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6323 - accuracy: 0.6410
# Epoch 88/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6320 - accuracy: 0.6405
# Epoch 89/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6320 - accuracy: 0.6403
# Epoch 90/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6317 - accuracy: 0.6414
# Epoch 91/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6315 - accuracy: 0.6421
# Epoch 92/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6312 - accuracy: 0.6413
# Epoch 93/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6309 - accuracy: 0.6422
# Epoch 94/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6307 - accuracy: 0.6417
# Epoch 95/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6307 - accuracy: 0.6420
# Epoch 96/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6303 - accuracy: 0.6428
# Epoch 97/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6305 - accuracy: 0.6427
# Epoch 98/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6299 - accuracy: 0.6434
# Epoch 99/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6298 - accuracy: 0.6430
# Epoch 100/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6294 - accuracy: 0.6434
# Epoch 1/100
# 2994/2994 [==============================] - 36s 12ms/step - loss: 0.6977 - accuracy: 0.5282
# Epoch 2/100
# 2994/2994 [==============================] - 40s 13ms/step - loss: 0.6897 - accuracy: 0.5375
# Epoch 3/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6882 - accuracy: 0.5430
# Epoch 4/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6869 - accuracy: 0.5477
# Epoch 5/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6854 - accuracy: 0.5520
# Epoch 6/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6841 - accuracy: 0.5553
# Epoch 7/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6826 - accuracy: 0.5593
# Epoch 8/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6811 - accuracy: 0.5624
# Epoch 9/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6799 - accuracy: 0.5656
# Epoch 10/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6785 - accuracy: 0.5684
# Epoch 11/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6770 - accuracy: 0.5714
# Epoch 12/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6757 - accuracy: 0.5742
# Epoch 13/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6743 - accuracy: 0.5764
# Epoch 14/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6728 - accuracy: 0.5796
# Epoch 15/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6714 - accuracy: 0.5820
# Epoch 16/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6706 - accuracy: 0.5831
# Epoch 17/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6690 - accuracy: 0.5863
# Epoch 18/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6683 - accuracy: 0.5870
# Epoch 19/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6668 - accuracy: 0.5900
# Epoch 20/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6658 - accuracy: 0.5914
# Epoch 21/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6650 - accuracy: 0.5937
# Epoch 22/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6638 - accuracy: 0.5952
# Epoch 23/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6630 - accuracy: 0.59620s - loss: 0.6629 - accuracy:
# Epoch 24/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6622 - accuracy: 0.5980
# Epoch 25/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6614 - accuracy: 0.5994
# Epoch 26/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6605 - accuracy: 0.6000
# Epoch 27/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6597 - accuracy: 0.6021
# Epoch 28/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6589 - accuracy: 0.6036
# Epoch 29/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6581 - accuracy: 0.6043
# Epoch 30/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6573 - accuracy: 0.6054
# Epoch 31/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6567 - accuracy: 0.6065
# Epoch 32/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6558 - accuracy: 0.6074
# Epoch 33/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6554 - accuracy: 0.6095
# Epoch 34/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6547 - accuracy: 0.6095
# Epoch 35/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6537 - accuracy: 0.6113
# Epoch 36/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6536 - accuracy: 0.6111
# Epoch 37/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6530 - accuracy: 0.6127
# Epoch 38/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6525 - accuracy: 0.6133
# Epoch 39/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6514 - accuracy: 0.6144
# Epoch 40/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6514 - accuracy: 0.6145
# Epoch 41/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6506 - accuracy: 0.6160
# Epoch 42/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6502 - accuracy: 0.6167
# Epoch 43/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6494 - accuracy: 0.6171
# Epoch 44/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6494 - accuracy: 0.6184
# Epoch 45/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6486 - accuracy: 0.6192
# Epoch 46/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6480 - accuracy: 0.6196
# Epoch 47/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6477 - accuracy: 0.6199
# Epoch 48/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6472 - accuracy: 0.6211
# Epoch 49/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6467 - accuracy: 0.6212
# Epoch 50/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6463 - accuracy: 0.6226
# Epoch 51/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6459 - accuracy: 0.6226
# Epoch 52/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6454 - accuracy: 0.6233
# Epoch 53/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6445 - accuracy: 0.6249
# Epoch 54/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6442 - accuracy: 0.6246
# Epoch 55/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6443 - accuracy: 0.6250
# Epoch 56/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6440 - accuracy: 0.6256
# Epoch 57/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6431 - accuracy: 0.6264
# Epoch 58/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6421 - accuracy: 0.6279
# Epoch 59/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6421 - accuracy: 0.6275
# Epoch 60/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6425 - accuracy: 0.6270
# Epoch 61/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6417 - accuracy: 0.6281
# Epoch 62/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6413 - accuracy: 0.6289
# Epoch 63/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6409 - accuracy: 0.6296
# Epoch 64/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6402 - accuracy: 0.6299
# Epoch 65/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6400 - accuracy: 0.6305
# Epoch 66/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6392 - accuracy: 0.6308
# Epoch 67/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6391 - accuracy: 0.6315
# Epoch 68/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6389 - accuracy: 0.6321
# Epoch 69/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6387 - accuracy: 0.6320
# Epoch 70/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6384 - accuracy: 0.6325
# Epoch 71/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6385 - accuracy: 0.6328
# Epoch 72/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6376 - accuracy: 0.6337
# Epoch 73/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6374 - accuracy: 0.6338
# Epoch 74/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6372 - accuracy: 0.6338
# Epoch 75/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6369 - accuracy: 0.6342
# Epoch 76/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6367 - accuracy: 0.6341
# Epoch 77/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6362 - accuracy: 0.6354
# Epoch 78/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6363 - accuracy: 0.6357
# Epoch 79/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6355 - accuracy: 0.6361
# Epoch 80/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6358 - accuracy: 0.6356
# Epoch 81/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6354 - accuracy: 0.6365
# Epoch 82/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6353 - accuracy: 0.6363
# Epoch 83/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6340 - accuracy: 0.6379
# Epoch 84/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6343 - accuracy: 0.6370
# Epoch 85/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6348 - accuracy: 0.6372
# Epoch 86/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6340 - accuracy: 0.6379
# Epoch 87/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6339 - accuracy: 0.6377
# Epoch 88/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6336 - accuracy: 0.6380
# Epoch 89/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6333 - accuracy: 0.6383
# Epoch 90/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6332 - accuracy: 0.6393
# Epoch 91/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6332 - accuracy: 0.6391
# Epoch 92/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6325 - accuracy: 0.6400
# Epoch 93/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6319 - accuracy: 0.6407
# Epoch 94/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6322 - accuracy: 0.6408
# Epoch 95/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6324 - accuracy: 0.6404
# Epoch 96/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6319 - accuracy: 0.6406
# Epoch 97/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6315 - accuracy: 0.6403
# Epoch 98/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6315 - accuracy: 0.6409
# Epoch 99/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6315 - accuracy: 0.6412
# Epoch 100/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6309 - accuracy: 0.6416
# Epoch 1/100
# 2994/2994 [==============================] - 36s 12ms/step - loss: 0.6979 - accuracy: 0.5296
# Epoch 2/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6892 - accuracy: 0.5398
# Epoch 3/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6878 - accuracy: 0.5452
# Epoch 4/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6863 - accuracy: 0.5499
# Epoch 5/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6848 - accuracy: 0.5543
# Epoch 6/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6832 - accuracy: 0.5578
# Epoch 7/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6818 - accuracy: 0.5616
# Epoch 8/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6803 - accuracy: 0.5661
# Epoch 9/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6791 - accuracy: 0.5687
# Epoch 10/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6776 - accuracy: 0.5717
# Epoch 11/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6762 - accuracy: 0.5740
# Epoch 12/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6747 - accuracy: 0.5772
# Epoch 13/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6735 - accuracy: 0.5795
# Epoch 14/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6720 - accuracy: 0.5829
# Epoch 15/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6708 - accuracy: 0.5847
# Epoch 16/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6694 - accuracy: 0.5868
# Epoch 17/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6683 - accuracy: 0.5888
# Epoch 18/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6671 - accuracy: 0.5907
# Epoch 19/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6657 - accuracy: 0.5936
# Epoch 20/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6649 - accuracy: 0.5949
# Epoch 21/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6637 - accuracy: 0.5963
# Epoch 22/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6628 - accuracy: 0.5978
# Epoch 23/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6624 - accuracy: 0.5985
# Epoch 24/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6610 - accuracy: 0.6010
# Epoch 25/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6602 - accuracy: 0.6023
# Epoch 26/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6594 - accuracy: 0.6027
# Epoch 27/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6585 - accuracy: 0.6048
# Epoch 28/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6582 - accuracy: 0.6058
# Epoch 29/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6574 - accuracy: 0.6069
# Epoch 30/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6566 - accuracy: 0.6079
# Epoch 31/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6561 - accuracy: 0.6079
# Epoch 32/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6551 - accuracy: 0.6099
# Epoch 33/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6547 - accuracy: 0.6107
# Epoch 34/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6536 - accuracy: 0.6117
# Epoch 35/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6531 - accuracy: 0.6130
# Epoch 36/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6526 - accuracy: 0.6131
# Epoch 37/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6517 - accuracy: 0.6144
# Epoch 38/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6512 - accuracy: 0.6154
# Epoch 39/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6506 - accuracy: 0.6161
# Epoch 40/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6500 - accuracy: 0.6168
# Epoch 41/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6494 - accuracy: 0.6183
# Epoch 42/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6490 - accuracy: 0.6180
# Epoch 43/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6482 - accuracy: 0.6198
# Epoch 44/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6480 - accuracy: 0.6198
# Epoch 45/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6473 - accuracy: 0.6209
# Epoch 46/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6472 - accuracy: 0.6218
# Epoch 47/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6463 - accuracy: 0.6222
# Epoch 48/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6456 - accuracy: 0.6236
# Epoch 49/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6450 - accuracy: 0.6241
# Epoch 50/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6443 - accuracy: 0.6251
# Epoch 51/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6445 - accuracy: 0.6253
# Epoch 52/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6438 - accuracy: 0.6261
# Epoch 53/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6437 - accuracy: 0.6263
# Epoch 54/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6429 - accuracy: 0.6268
# Epoch 55/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6424 - accuracy: 0.6284
# Epoch 56/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6421 - accuracy: 0.6282
# Epoch 57/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6423 - accuracy: 0.6282
# Epoch 58/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6419 - accuracy: 0.6284
# Epoch 59/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6415 - accuracy: 0.6288
# Epoch 60/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6406 - accuracy: 0.6300
# Epoch 61/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6403 - accuracy: 0.6305
# Epoch 62/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6403 - accuracy: 0.6305
# Epoch 63/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6396 - accuracy: 0.6315
# Epoch 64/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6392 - accuracy: 0.6311
# Epoch 65/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6392 - accuracy: 0.6322
# Epoch 66/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6386 - accuracy: 0.6327
# Epoch 67/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6380 - accuracy: 0.6340
# Epoch 68/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6384 - accuracy: 0.6324
# Epoch 69/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6374 - accuracy: 0.6346
# Epoch 70/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6371 - accuracy: 0.6351
# Epoch 71/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6369 - accuracy: 0.6354
# Epoch 72/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6365 - accuracy: 0.6354
# Epoch 73/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6363 - accuracy: 0.6365
# Epoch 74/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6360 - accuracy: 0.6364
# Epoch 75/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6354 - accuracy: 0.6370
# Epoch 76/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6356 - accuracy: 0.6361
# Epoch 77/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6355 - accuracy: 0.6365
# Epoch 78/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6353 - accuracy: 0.6367
# Epoch 79/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6349 - accuracy: 0.6378
# Epoch 80/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6345 - accuracy: 0.6379
# Epoch 81/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6342 - accuracy: 0.6387
# Epoch 82/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6339 - accuracy: 0.6387
# Epoch 83/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6336 - accuracy: 0.6397
# Epoch 84/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6333 - accuracy: 0.6399
# Epoch 85/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6330 - accuracy: 0.6395
# Epoch 86/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6326 - accuracy: 0.6397
# Epoch 87/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6323 - accuracy: 0.6403
# Epoch 88/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6324 - accuracy: 0.6397
# Epoch 89/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6317 - accuracy: 0.6410
# Epoch 90/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6318 - accuracy: 0.6414
# Epoch 91/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6315 - accuracy: 0.6412
# Epoch 92/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6310 - accuracy: 0.6417
# Epoch 93/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6311 - accuracy: 0.6422
# Epoch 94/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6306 - accuracy: 0.6431
# Epoch 95/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6308 - accuracy: 0.6421
# Epoch 96/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6299 - accuracy: 0.6435
# Epoch 97/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6299 - accuracy: 0.6436
# Epoch 98/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6302 - accuracy: 0.6431
# Epoch 99/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6304 - accuracy: 0.6426
# Epoch 100/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6294 - accuracy: 0.6439
# Epoch 1/100
# 2994/2994 [==============================] - 36s 12ms/step - loss: 0.6972 - accuracy: 0.5311
# Epoch 2/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6889 - accuracy: 0.5407
# Epoch 3/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6876 - accuracy: 0.5455
# Epoch 4/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6862 - accuracy: 0.5500
# Epoch 5/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6847 - accuracy: 0.5543
# Epoch 6/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6833 - accuracy: 0.5583
# Epoch 7/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6818 - accuracy: 0.5612
# Epoch 8/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6803 - accuracy: 0.5649
# Epoch 9/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6790 - accuracy: 0.5687
# Epoch 10/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6777 - accuracy: 0.5712
# Epoch 11/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6764 - accuracy: 0.5735
# Epoch 12/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6749 - accuracy: 0.5764
# Epoch 13/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6733 - accuracy: 0.5795
# Epoch 14/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6720 - accuracy: 0.5810
# Epoch 15/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6708 - accuracy: 0.5834
# Epoch 16/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6697 - accuracy: 0.5859
# Epoch 17/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6685 - accuracy: 0.5875
# Epoch 18/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6675 - accuracy: 0.5890
# Epoch 19/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6664 - accuracy: 0.5915
# Epoch 20/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6655 - accuracy: 0.5928
# Epoch 21/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6642 - accuracy: 0.5953
# Epoch 22/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6634 - accuracy: 0.5962
# Epoch 23/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6629 - accuracy: 0.5964
# Epoch 24/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6617 - accuracy: 0.5990
# Epoch 25/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6606 - accuracy: 0.6010
# Epoch 26/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6600 - accuracy: 0.6020
# Epoch 27/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6588 - accuracy: 0.6029
# Epoch 28/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6584 - accuracy: 0.6038
# Epoch 29/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6576 - accuracy: 0.6055
# Epoch 30/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6568 - accuracy: 0.6062
# Epoch 31/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6561 - accuracy: 0.6077
# Epoch 32/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6551 - accuracy: 0.6091
# Epoch 33/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6546 - accuracy: 0.6101
# Epoch 34/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6541 - accuracy: 0.6110
# Epoch 35/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6530 - accuracy: 0.6124
# Epoch 36/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6526 - accuracy: 0.6130
# Epoch 37/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6517 - accuracy: 0.6143
# Epoch 38/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6514 - accuracy: 0.6145
# Epoch 39/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6506 - accuracy: 0.6157
# Epoch 40/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6500 - accuracy: 0.6165
# Epoch 41/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6497 - accuracy: 0.6171
# Epoch 42/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6494 - accuracy: 0.6171
# Epoch 43/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6488 - accuracy: 0.6186
# Epoch 44/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6482 - accuracy: 0.6194
# Epoch 45/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6474 - accuracy: 0.6207
# Epoch 46/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6470 - accuracy: 0.6202
# Epoch 47/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6462 - accuracy: 0.6223
# Epoch 48/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6458 - accuracy: 0.6225
# Epoch 49/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6457 - accuracy: 0.6224
# Epoch 50/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6451 - accuracy: 0.6235
# Epoch 51/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6445 - accuracy: 0.6246
# Epoch 52/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6442 - accuracy: 0.6252
# Epoch 53/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6432 - accuracy: 0.6260
# Epoch 54/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6436 - accuracy: 0.6261
# Epoch 55/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6431 - accuracy: 0.6271
# Epoch 56/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6422 - accuracy: 0.6277
# Epoch 57/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6418 - accuracy: 0.6287
# Epoch 58/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6416 - accuracy: 0.6290
# Epoch 59/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6418 - accuracy: 0.6288
# Epoch 60/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6413 - accuracy: 0.6287
# Epoch 61/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6411 - accuracy: 0.6294
# Epoch 62/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6404 - accuracy: 0.6296
# Epoch 63/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6397 - accuracy: 0.6311
# Epoch 64/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6395 - accuracy: 0.6312
# Epoch 65/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6395 - accuracy: 0.6307
# Epoch 66/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6391 - accuracy: 0.6313
# Epoch 67/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6387 - accuracy: 0.6324
# Epoch 68/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6380 - accuracy: 0.6332
# Epoch 69/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6379 - accuracy: 0.6335
# Epoch 70/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6371 - accuracy: 0.6341
# Epoch 71/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6379 - accuracy: 0.6331
# Epoch 72/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6377 - accuracy: 0.6335
# Epoch 73/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6366 - accuracy: 0.6343
# Epoch 74/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6364 - accuracy: 0.6352
# Epoch 75/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6366 - accuracy: 0.6350
# Epoch 76/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6354 - accuracy: 0.6368
# Epoch 77/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6353 - accuracy: 0.6364
# Epoch 78/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6352 - accuracy: 0.6368
# Epoch 79/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6350 - accuracy: 0.6373
# Epoch 80/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6351 - accuracy: 0.6368
# Epoch 81/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6344 - accuracy: 0.6374
# Epoch 82/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6344 - accuracy: 0.6376
# Epoch 83/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6336 - accuracy: 0.6384
# Epoch 84/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6338 - accuracy: 0.6385
# Epoch 85/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6334 - accuracy: 0.6390
# Epoch 86/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6333 - accuracy: 0.6393
# Epoch 87/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6331 - accuracy: 0.6395
# Epoch 88/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6328 - accuracy: 0.6396
# Epoch 89/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6322 - accuracy: 0.6404
# Epoch 90/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6320 - accuracy: 0.6403
# Epoch 91/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6317 - accuracy: 0.6405
# Epoch 92/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6321 - accuracy: 0.6408
# Epoch 93/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6315 - accuracy: 0.6412
# Epoch 94/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6309 - accuracy: 0.6417
# Epoch 95/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6309 - accuracy: 0.6415
# Epoch 96/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6305 - accuracy: 0.6428
# Epoch 97/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6299 - accuracy: 0.6430
# Epoch 98/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6301 - accuracy: 0.6422
# Epoch 99/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6300 - accuracy: 0.6424
# Epoch 100/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6298 - accuracy: 0.6428
# Epoch 1/100
# 2994/2994 [==============================] - 36s 12ms/step - loss: 0.6974 - accuracy: 0.5314
# Epoch 2/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6891 - accuracy: 0.5399
# Epoch 3/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6875 - accuracy: 0.5457
# Epoch 4/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6862 - accuracy: 0.5497
# Epoch 5/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6846 - accuracy: 0.5543
# Epoch 6/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6831 - accuracy: 0.5584
# Epoch 7/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6816 - accuracy: 0.5624
# Epoch 8/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6802 - accuracy: 0.5655
# Epoch 9/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6788 - accuracy: 0.5687
# Epoch 10/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6773 - accuracy: 0.5714
# Epoch 11/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6758 - accuracy: 0.5755
# Epoch 12/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6745 - accuracy: 0.5773
# Epoch 13/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6732 - accuracy: 0.5798
# Epoch 14/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6716 - accuracy: 0.5827
# Epoch 15/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6703 - accuracy: 0.5850
# Epoch 16/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6692 - accuracy: 0.5870
# Epoch 17/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6681 - accuracy: 0.5883
# Epoch 18/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6671 - accuracy: 0.5906
# Epoch 19/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6659 - accuracy: 0.5927
# Epoch 20/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6646 - accuracy: 0.5949
# Epoch 21/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6639 - accuracy: 0.5961
# Epoch 22/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6626 - accuracy: 0.5976
# Epoch 23/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6621 - accuracy: 0.5987
# Epoch 24/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6610 - accuracy: 0.5999
# Epoch 25/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6602 - accuracy: 0.6020
# Epoch 26/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6591 - accuracy: 0.6037
# Epoch 27/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6584 - accuracy: 0.6037
# Epoch 28/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6578 - accuracy: 0.6050
# Epoch 29/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6568 - accuracy: 0.6071
# Epoch 30/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6559 - accuracy: 0.6078
# Epoch 31/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6555 - accuracy: 0.6088
# Epoch 32/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6548 - accuracy: 0.6105
# Epoch 33/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6545 - accuracy: 0.6106
# Epoch 34/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6535 - accuracy: 0.6124
# Epoch 35/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6527 - accuracy: 0.6137
# Epoch 36/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6519 - accuracy: 0.6151
# Epoch 37/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6520 - accuracy: 0.6145
# Epoch 38/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6511 - accuracy: 0.6160
# Epoch 39/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6503 - accuracy: 0.6168
# Epoch 40/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6496 - accuracy: 0.6181
# Epoch 41/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6491 - accuracy: 0.6182
# Epoch 42/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6488 - accuracy: 0.6191
# Epoch 43/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6481 - accuracy: 0.6200
# Epoch 44/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6475 - accuracy: 0.6208
# Epoch 45/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6466 - accuracy: 0.6211
# Epoch 46/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6463 - accuracy: 0.6222
# Epoch 47/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6460 - accuracy: 0.6234
# Epoch 48/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6452 - accuracy: 0.6237
# Epoch 49/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6449 - accuracy: 0.6245
# Epoch 50/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6448 - accuracy: 0.6244
# Epoch 51/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6441 - accuracy: 0.6257
# Epoch 52/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6436 - accuracy: 0.6257
# Epoch 53/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6434 - accuracy: 0.6266
# Epoch 54/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6430 - accuracy: 0.6267
# Epoch 55/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6421 - accuracy: 0.6283
# Epoch 56/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6422 - accuracy: 0.6279
# Epoch 57/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6417 - accuracy: 0.6283
# Epoch 58/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6410 - accuracy: 0.6293
# Epoch 59/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6409 - accuracy: 0.6298
# Epoch 60/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6406 - accuracy: 0.6300
# Epoch 61/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6399 - accuracy: 0.6305
# Epoch 62/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6396 - accuracy: 0.6311
# Epoch 63/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6393 - accuracy: 0.6316
# Epoch 64/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6387 - accuracy: 0.6321
# Epoch 65/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6386 - accuracy: 0.6322
# Epoch 66/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6387 - accuracy: 0.6324
# Epoch 67/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6381 - accuracy: 0.6337
# Epoch 68/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6376 - accuracy: 0.6344
# Epoch 69/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6376 - accuracy: 0.6337
# Epoch 70/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6369 - accuracy: 0.6350
# Epoch 71/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6364 - accuracy: 0.6360
# Epoch 72/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6370 - accuracy: 0.6347
# Epoch 73/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6361 - accuracy: 0.6359
# Epoch 74/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6353 - accuracy: 0.6376
# Epoch 75/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6356 - accuracy: 0.6363
# Epoch 76/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6357 - accuracy: 0.6363
# Epoch 77/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6348 - accuracy: 0.6370
# Epoch 78/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6346 - accuracy: 0.6374
# Epoch 79/100
# 2994/2994 [==============================] - 37s 12ms/step - loss: 0.6345 - accuracy: 0.6376
# Epoch 80/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6341 - accuracy: 0.6377
# Epoch 81/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6337 - accuracy: 0.6393
# Epoch 82/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6334 - accuracy: 0.6387
# Epoch 83/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6337 - accuracy: 0.6389
# Epoch 84/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6333 - accuracy: 0.6391
# Epoch 85/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6329 - accuracy: 0.6397
# Epoch 86/100
# 2994/2994 [==============================] - 39s 13ms/step - loss: 0.6330 - accuracy: 0.6403
# Epoch 87/100
# 2994/2994 [==============================] - 37s 13ms/step - loss: 0.6326 - accuracy: 0.6400
# Epoch 88/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6321 - accuracy: 0.6410
# Epoch 89/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6320 - accuracy: 0.6405
# Epoch 90/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6317 - accuracy: 0.6408
# Epoch 91/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6312 - accuracy: 0.6415
# Epoch 92/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6315 - accuracy: 0.6412
# Epoch 93/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6307 - accuracy: 0.6419
# Epoch 94/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6307 - accuracy: 0.6427
# Epoch 95/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6306 - accuracy: 0.6424
# Epoch 96/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6302 - accuracy: 0.6427
# Epoch 97/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6303 - accuracy: 0.6421
# Epoch 98/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6301 - accuracy: 0.6427
# Epoch 99/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6299 - accuracy: 0.6429
# Epoch 100/100
# 2994/2994 [==============================] - 38s 13ms/step - loss: 0.6290 - accuracy: 0.6445
# CPU times: user 17h 31min 59s, sys: 6h 29min 10s, total: 1d 1min 9s
# Wall time: 5h 18min 31s
# (0.542011771614248, 'not good')

# %% [markdown]
# ## optuna code

# %%
# adapted from https://github.com/optuna/optuna-examples/blob/2460c9196389031b869b110171c48215426fc2d9/tensorflow/tensorflow_eager_simple.py
"""
Optuna example that optimizes multi-layer perceptrons using Tensorflow (Eager Execution).
In this example, we optimize the validation accuracy of hand-written digit recognition using
Tensorflow and MNIST. We optimize the neural network architecture as well as the optimizer
configuration.
"""

import urllib

import optuna
from packaging import version

import tensorflow as tf
from tensorflow.keras.datasets import mnist


# TODO(crcrpar): Remove the below three lines once everything is ok.
# Register a global custom opener to avoid HTTP Error 403: Forbidden when downloading MNIST.
opener = urllib.request.build_opener()
opener.addheaders = [("User-agent", "Mozilla/5.0")]
urllib.request.install_opener(opener)


if version.parse(tf.__version__) < version.parse("2.0.0"):
    raise RuntimeError("tensorflow>=2.0.0 is required for this example.")

N_TRAIN_EXAMPLES = 3000
N_VALID_EXAMPLES = 1000
BATCHSIZE = 128
CLASSES = 10
EPOCHS = 1


def create_model(trial):
    # We optimize the numbers of layers, their units and weight decay parameter.
    n_layers = trial.suggest_int("n_layers", 1, 3)
    weight_decay = trial.suggest_float("weight_decay", 1e-10, 1e-3, log=True)
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Flatten())
    for i in range(n_layers):
        num_hidden = trial.suggest_int("n_units_l{}".format(i), 4, 128, log=True)
        model.add(
            tf.keras.layers.Dense(
                num_hidden,
                activation="relu",
                kernel_regularizer=tf.keras.regularizers.l2(weight_decay),
            )
        )
    model.add(
        tf.keras.layers.Dense(CLASSES, kernel_regularizer=tf.keras.regularizers.l2(weight_decay))
    )
    return model


def create_optimizer(trial):
    # We optimize the choice of optimizers as well as their parameters.
    kwargs = {}
    optimizer_options = ["RMSprop", "Adam", "SGD"]
    optimizer_selected = trial.suggest_categorical("optimizer", optimizer_options)
    if optimizer_selected == "RMSprop":
        kwargs["learning_rate"] = trial.suggest_float(
            "rmsprop_learning_rate", 1e-5, 1e-1, log=True
        )
        kwargs["decay"] = trial.suggest_float("rmsprop_decay", 0.85, 0.99)
        kwargs["momentum"] = trial.suggest_float("rmsprop_momentum", 1e-5, 1e-1, log=True)
    elif optimizer_selected == "Adam":
        kwargs["learning_rate"] = trial.suggest_float("adam_learning_rate", 1e-5, 1e-1, log=True)
    elif optimizer_selected == "SGD":
        kwargs["learning_rate"] = trial.suggest_float(
            "sgd_opt_learning_rate", 1e-5, 1e-1, log=True
        )
        kwargs["momentum"] = trial.suggest_float("sgd_opt_momentum", 1e-5, 1e-1, log=True)

    optimizer = getattr(tf.optimizers, optimizer_selected)(**kwargs)
    return optimizer


def learn(model, optimizer, dataset, mode="eval"):
    accuracy = tf.metrics.Accuracy("accuracy", dtype=tf.float32)

    for batch, (images, labels) in enumerate(dataset):
        with tf.GradientTape() as tape:
            logits = model(images, training=(mode == "train"))
            loss_value = tf.reduce_mean(
                tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=labels)
            )
            if mode == "eval":
                accuracy(
                    tf.argmax(logits, axis=1, output_type=tf.int64), tf.cast(labels, tf.int64)
                )
            else:
                grads = tape.gradient(loss_value, model.variables)
                optimizer.apply_gradients(zip(grads, model.variables))

    if mode == "eval":
        return accuracy


def get_mnist():
    (x_train, y_train), (x_valid, y_valid) = mnist.load_data()
    x_train = x_train.astype("float32") / 255
    x_valid = x_valid.astype("float32") / 255

    y_train = y_train.astype("int32")
    y_valid = y_valid.astype("int32")

    train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
    train_ds = train_ds.shuffle(60000).batch(BATCHSIZE).take(N_TRAIN_EXAMPLES)

    valid_ds = tf.data.Dataset.from_tensor_slices((x_valid, y_valid))
    valid_ds = valid_ds.shuffle(10000).batch(BATCHSIZE).take(N_VALID_EXAMPLES)
    return train_ds, valid_ds


# FYI: Objective functions can take additional arguments
# (https://optuna.readthedocs.io/en/stable/faq.html#objective-func-additional-args).
def objective(trial):
    # Get MNIST data.
    train_ds, valid_ds = get_mnist()

    # Build model and optimizer.
    model = create_model(trial)
    optimizer = create_optimizer(trial)

    # Training and validating cycle.
    with tf.device("/cpu:0"):
        for _ in range(EPOCHS):
            learn(model, optimizer, train_ds, "train")

        accuracy = learn(model, optimizer, valid_ds, "eval")

    # Return last validation accuracy.
    return accuracy.result()


# if __name__ == "__main__":
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)

print("Number of finished trials: ", len(study.trials))

print("Best trial:")
trial = study.best_trial

print("  Value: ", trial.value)

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
