# %% [markdown]
# https://matplotlib.org/3.4.3/gallery/ticks_and_spines/multiple_yaxis_with_spines.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame({"x": np.linspace(0, 2 * np.pi, 10000)})
df["y1"] = np.sin(df["x"])
df["y2"] = 10 * np.cos(df["x"])
df["y3"] = 1000 * df["x"]
df
# Out:
#              x            y1         y2           y3
# 0     0.000000  0.000000e+00  10.000000     0.000000
# 1     0.000628  6.283813e-04   9.999998     0.628381
# 2     0.001257  1.256762e-03   9.999992     1.256763
# 3     0.001885  1.885143e-03   9.999982     1.885144
# 4     0.002514  2.513523e-03   9.999968     2.513525
# ...        ...           ...        ...          ...
# 9995  6.280672 -2.513523e-03   9.999968  6280.671782
# 9996  6.281300 -1.885143e-03   9.999982  6281.300163
# 9997  6.281929 -1.256762e-03   9.999992  6281.928544
# 9998  6.282557 -6.283813e-04   9.999998  6282.556926
# 9999  6.283185 -2.449294e-16  10.000000  6283.185307
#
# [10000 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.lineplot(df, x="x", ax=ax, y="y1")
ax2 = ax.twinx()
sns.lineplot(df, x="x", ax=ax2, y="y2", color="orange")
ax3 = ax.twinx()
sns.lineplot(df, x="x", ax=ax2, y="y3", color="orange")
ax3.spines.right.set_position(("axes", 1.2))
