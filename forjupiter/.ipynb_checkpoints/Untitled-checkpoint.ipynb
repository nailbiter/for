# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
from pytz import timezone
from bson.codec_options import CodecOptions
import matplotlib.pyplot as plt
# %matplotlib inline

#global const's
WEEKS = 4
TIMESTAMPS_PER_HOUR = 2
#global var's
client = MongoClient('localhost', 27017)
coll = client.admin.passwords
doc = coll.find_one({"key":"MONGOMLAB"})
mongopass = doc["value"]
mongopass
# Out:
# 'cryuaCSujCio42'

# %%
client = MongoClient(f"mongodb://nailbiter:{mongopass}@ds149672.mlab.com:49672/logistics")
timecoll = client.logistics["alex.money"].with_options(codec_options=CodecOptions(tz_aware=True,tzinfo=timezone('Asia/Tokyo')))
df = pd.DataFrame(timecoll.find({"category":"food"}).sort("date",pymongo.DESCENDING))
# df.tags

# %% [markdown]
# ddf = df
# ddf["flag"] = ddf.tags.apply(lambda x:("subway" in x) if isinstance(x, list) else False)
# ddf[ddf.flag]

# %%
14190/377/2
# Out:
# 18.819628647214856
