# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
from pytz import timezone
from bson.codec_options import CodecOptions
import matplotlib.pyplot as plt
# %matplotlib inline

#global const's
WEEKS = 4
TIMESTAMPS_PER_HOUR = 2
#global var's
client = MongoClient('localhost', 27017)
coll = client.admin.passwords
doc = coll.find_one({"key":"MONGOMLAB"})
mongopass = doc["value"]
mongopass
# Out:
# 'cryuaCSujCio42'

# %% [markdown]
# # TODO
#
# * limit using date, not count
# * print dates explicitly in graphs

# %%
client = MongoClient(f"mongodb://nailbiter:{mongopass}@ds149672.mlab.com:49672/logistics")
timecoll = client.logistics["alex.time"].with_options(codec_options=CodecOptions(tz_aware=True,tzinfo=timezone('Asia/Tokyo')))
docs = list(obj for obj in timecoll.find().sort("date",pymongo.DESCENDING).limit((7*(WEEKS+1)+2)*24*TIMESTAMPS_PER_HOUR))

# %%
df = pd.DataFrame(docs)
df["week"] = df["date"].apply(lambda d:d.date().isocalendar()[1])
# df["weekday"] = df["date"].apply(lambda d:d.date().isocalendar()[2])
df["elapsed_hours"] = 1/TIMESTAMPS_PER_HOUR

last_week_idx = df["week"].max()
df = df[(last_week_idx > df["week"]) & (df["week"] >(last_week_idx-WEEKS-1))]

# df.groupby(["week","category"]).sum()
arr = dict()
cats = set()
for name,group in df.groupby(["week","category"]):
    (week,cat) = name
    if(week not in arr):
        arr[week] = dict()
    arr[week][cat] = group["elapsed_hours"].sum()
    arr[week]["week"] = week
    cats.add(cat)

# vals = arr.values()
# sorted(vals,key lambda d)
grouped_df = pd.DataFrame(arr.values())
grouped_df = grouped_df.fillna(0)
grouped_df = grouped_df.transpose()
grouped_df
# Out:
#               0     1     2     3
# coding      0.5   0.0   0.0   1.5
# week        7.0   8.0   9.0  10.0
# gym         5.0   1.0   5.0   2.0
# logistics  10.0   7.0   3.0   2.0
# parttime   47.0  60.0  49.5  35.5
# rest        0.5   0.0   0.5   0.0
# sleeping   57.0  91.0  70.0  38.5
# social     34.0   6.5  36.0  37.0
# useless    14.0   2.5   4.0  51.5

# %%
for i in range(WEEKS):
    fig = plt.figure(i+1)
    plt.title(grouped_df[i]["week"])
    grouped_df[i]
    grouped_df[i] = grouped_df[i].drop("week")
    grouped_df[i].plot.pie(figsize=(16,10),autopct="%.2f")

# %%
client = MongoClient(f"mongodb://nailbiter:{mongopass}@ds149672.mlab.com:49672/logistics")
timecoll = client.logistics["alex.money"].with_options(codec_options=CodecOptions(tz_aware=True,tzinfo=timezone('Asia/Tokyo')))
docs = list(obj for obj in timecoll.find().sort("date",pymongo.DESCENDING))

# %%
df = pd.DataFrame(docs)
df["week"] = df["date"].apply(lambda d:d.date().isocalendar()[1])
# df["weekday"] = df["date"].apply(lambda d:d.date().isocalendar()[2])

last_week_idx = df["week"].max()
df = df[(last_week_idx > df["week"]) & (df["week"] >(last_week_idx-WEEKS-1))]

# df.groupby(["week","category"]).sum()
arr = dict()
cats = set()
for name,group in df.groupby(["week","category"]):
    (week,cat) = name
    if(week not in arr):
        arr[week] = dict()
    arr[week][cat] = group["amount"].sum()
    arr[week]["week"] = week
    cats.add(cat)

# vals = arr.values()
# sorted(vals,key lambda d)
grouped_df = pd.DataFrame(arr.values())
grouped_df = grouped_df.fillna(0)
grouped_df = grouped_df.set_index("week")
grouped_df
# Out:
#           food      fun
# week
# 48    166572.0  39170.0
# 49     29895.0  63348.0
# 50     64877.0  50733.0
# 51     25424.0  57231.0

# %%
plt.figure()
grouped_df.plot.bar(figsize=(16,10),stacked=True)
