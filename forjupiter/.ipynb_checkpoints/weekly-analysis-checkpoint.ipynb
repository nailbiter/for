# %%
import pymongo
from pymongo import MongoClient
import pandas as pd

client = MongoClient('localhost', 27017)
coll = client.admin.passwords
doc = coll.find_one({"key":"MONGOMLAB"})
mongopass = doc["value"]

# %%
client = MongoClient(f"mongodb://nailbiter:{mongopass}@ds149672.mlab.com:49672/logistics")
timecoll = client.logistics["alex.time"]
docs = [obj for obj in timecoll.find().sort("date",pymongo.DESCENDING).limit(100)]
pd.DataFrame(docs)
# Out:
#                          _id                    date  category
# 0   5e5bd4f844268d5570d0f660 2020-03-01 15:30:00.003  sleeping
# 1   5e5bcf0e44268d5570d0f65c 2020-03-01 15:04:46.625    social
# 2   5e5bc7fe44268d5570d0f65a 2020-03-01 14:34:38.984    social
# 3   5e5bc28544268d5570d0f658 2020-03-01 14:11:17.742    social
# 4   5e5bb8e744268d5570d0f655 2020-03-01 13:30:15.035    social
# ..                       ...                     ...       ...
# 95  5e593ae544268d5570d0f5cf 2020-02-28 16:08:05.313  parttime
# 96  5e5938bf44268d5570d0f5ce 2020-02-28 15:58:55.621    social
# 97  5e592d1a44268d5570d0f5cd 2020-02-28 15:09:14.661       gym
# 98  5e592af044268d5570d0f5cb 2020-02-28 15:00:00.008   useless
# 99  5e5923e844268d5570d0f5c9 2020-02-28 14:30:00.015   useless
#
# [100 rows x 3 columns]
