# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
from pytz import timezone
from bson.codec_options import CodecOptions
import matplotlib.pyplot as plt
# %matplotlib inline

#global const's
WEEKS = 8
TIMESTAMPS_PER_HOUR = 2
#global var's
client = MongoClient('localhost', 27017)
coll = client.admin.passwords
doc = coll.find_one({"key":"MONGOMLAB"})
mongopass = doc["value"]
# mongopass

# %% [markdown]
# # TODO
#
# * limit using date, not count
# * print dates explicitly in graphs (**done**)

# %%
client = MongoClient(f"mongodb://nailbiter:{mongopass}@ds149672.mlab.com:49672/logistics")
timecoll = client.logistics["alex.time"].with_options(codec_options=CodecOptions(tz_aware=True,tzinfo=timezone('Asia/Tokyo')))
docs = list(obj for obj in timecoll.find().sort("date",pymongo.DESCENDING).limit((7*(WEEKS+1)+2)*24*TIMESTAMPS_PER_HOUR))
money_df = pd.DataFrame(docs)

# %%
money_df["week"] = money_df["date"].apply(lambda d:d.date().isocalendar()[1])
money_df["elapsed_hours"] = 1/TIMESTAMPS_PER_HOUR

last_week_idx = money_df["week"].max()
money_df = money_df[(last_week_idx > money_df["week"]) & (money_df["week"] >(last_week_idx-WEEKS-1))]

arr = dict()
cats = set()
for name,group in money_df.groupby(["week","category"]):
    (week,cat) = name
    if(week not in arr):
        arr[week] = dict()
    arr[week][cat] = group["elapsed_hours"].sum()
    arr[week]["date"] = group["date"].min().date()
    cats.add(cat)

money_grouped_df = pd.DataFrame(arr.values())
money_grouped_df = money_grouped_df.fillna(0)
money_grouped_df = money_grouped_df.transpose()
money_grouped_df
# Out:
#                     0           1           2           3           4  \
# coding            0.5           0           0         1.5         1.5
# date       2020-02-10  2020-02-19  2020-02-24  2020-03-05  2020-03-13
# gym                 5           1           5           2         5.5
# logistics          10           7           3           2         6.5
# parttime           47          60        49.5        35.5          55
# rest              0.5           0         0.5           0           2
# sleeping           57          91          70        38.5          69
# social             34         6.5          36          37        21.5
# useless            14         2.5           4        51.5         1.5
# german              0           0           0           0         5.5
#
#                     5           6           7
# coding            0.5           0           0
# date       2020-03-16  2020-03-23  2020-03-30
# gym                 4           2         1.5
# logistics         8.5          11           5
# parttime           40        21.5          37
# rest                2           0         1.5
# sleeping         65.5          61          90
# social           44.5        25.5          31
# useless             0          47           0
# german              3           0           2

# %%
for i in range(WEEKS):
    fig = plt.figure(i+1)
    plt.title(money_grouped_df[i]["date"])
    money_grouped_df[i]
    money_grouped_df[i] = money_grouped_df[i].drop("date")
    money_grouped_df[i].plot.pie(figsize=(16,10),autopct="%.2f")

# %%
client = MongoClient(f"mongodb://nailbiter:{mongopass}@ds149672.mlab.com:49672/logistics")
timecoll = client.logistics["alex.money"].with_options(codec_options=CodecOptions(tz_aware=True,tzinfo=timezone('Asia/Tokyo')))
time_df = pd.DataFrame(timecoll.find().sort("date",pymongo.DESCENDING))

# %%
time_df["week"] = time_df["date"].apply(lambda d:d.date().isocalendar()[1])
time_df["year"] = time_df["date"].apply(lambda d:d.date().isocalendar()[0])

last_week_idx = time_df.iloc[0].week
year = time_df.iloc[0].year
time_df = time_df[(last_week_idx > time_df["week"]) & (time_df["week"] >(last_week_idx-WEEKS-1)) & (time_df["year"]==year)]

arr = dict()
cats = set()
for name,group in time_df.groupby(["week","category"]):
    (week,cat) = name
    if(week not in arr):
        arr[week] = dict()
    arr[week][cat] = group["amount"].sum()
    arr[week]["date"] = group["date"].min().date()
    cats.add(cat)

time_grouped_df = pd.DataFrame(arr.values())
time_grouped_df = time_grouped_df.fillna(0)
time_grouped_df = time_grouped_df.set_index("date")
time_grouped_df
# Out:
#                 food       fun
# date
# 2020-02-15   27220.0    5588.0
# 2020-02-17   11010.0       0.0
# 2020-02-24   13269.0  137493.0
# 2020-03-02    7110.0   20903.0
# 2020-03-09    9767.0   26569.0
# 2020-03-22   10583.0    5853.0
# 2020-03-27  153093.0   18147.0
# 2020-04-05   20352.0    5919.0

# %%
plt.figure()
time_grouped_df.plot.bar(figsize=(16,10),stacked=True)
