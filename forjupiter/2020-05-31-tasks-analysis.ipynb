# %%
from pymongo import MongoClient
client = MongoClient()
mongo_pass = client.admin.passwords.find_one({"key":"MONGOMLAB"})["value"]

# %%
from pymongo import MongoClient
from pandas import DataFrame

client = MongoClient(f"mongodb://nailbiter:{mongo_pass}@ds149672.mlab.com:49672/logistics?authSource=logistics&readPreference=primary&appname=MongoDB%20Compass&ssl=false")
# mongo_pass
docs = [d for d in client.logistics["alex.taskLog"].find({"message":"taskdone"})]
# df = DataFrame(docs)

# %%
from pandas import DataFrame

processed_docs = sorted([
        {**d,"labels":[l["name"] for l in d["obj"]["labels"]],"name":d["obj"]["name"]}
        for d in docs 
        if type(d["date"])!=str],
        key=lambda d:d["date"],
        reverse=True)
processed_docs = [d for d in processed_docs if "parttime" in d["labels"]]
df = DataFrame(processed_docs).drop(labels=["message","obj","_id"],axis=1)
df[:20]
# Out:
#                       date                   labels                                               name
# 0  2020-05-29 22:50:37.845            [parttime, !]                                  candy return 2000
# 1  2020-05-27 05:40:36.810            [parttime, !]                          finish pullups 2020-05-25
# 2  2020-05-27 05:38:38.602            [parttime, !]                                       mobile money
# 3  2020-05-27 00:32:52.435            [parttime, !]               fix time, good day, sleep 2020-05-26
# 4  2020-05-22 00:50:40.690            [parttime, !]   horikoshi-san infectuous disease simulation idea
# 5  2020-05-15 15:43:28.403            [parttime, !]                                         masha task
# 6  2020-05-14 02:18:43.097  [parttime, DS, !, andy]                               acomposer dismantled
# 7  2020-05-14 02:17:12.163            [parttime, !]        work starti time 05/12 09:59 change oversee
# ...
