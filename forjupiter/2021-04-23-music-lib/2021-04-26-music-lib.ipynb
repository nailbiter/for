# %%
from alex_python_toolbox import google_drive
creds = google_drive.get_creds("client_secret.json",create_if_not_exist=True)
music_df = google_drive.download_df_from_google_sheets(creds,"1geXOAlLT7X0ig0r7jxbUPG-F_rnUyGKDnZr2pAeClak")

# %%
music_df.groupby(["author","album"]).agg({"filename":len}).sort_values(by="filename",ascending=False)
# Out:
#                                                   filename
# author         album
#                                                      14233
# Стивен Кинг    Темная Башня 5_ Волки Кальи             257
#                Глаз Дракона                            142
#                Needful Things                          135
#                Бессонница                              121
# Роджер Желязны Князь Света                             118
# Стивен Кинг    Роза Марена                              93
# Станислав Лем  Кибериада                                86
# Стивен Кинг    Возрождение                              85
# Ярослав Гашек  Похождения бравого солдата Швейка        82
# Стивен Кинг    Томминокеры                              77
#                Кладбище домашних животных               63
#                Кристина                                 50
# Дэвид Марусек  Счёт по головам                          46
# Чак Паланик    Бойцовски клуб                           36
# BadComedian                                             24
# Стивен Кинг                                             23
# #####          Demo                                     21
# Стивен Кинг    Полицейский из библиотеки                16
# Nigel Stanford Cymatics                                  9
# Харлан Элисон  Мальчик и его Собака                      9
# Стивен Кинг    Ящик                                      8
# Nina Nesbitt                                             1
# GAZIROVKA                                                1
# Пол Андерсон                                             1
# Андрей Дашков                                            1
# Call Me Loop                                             1
# Гарри Гаррисон                                           1
# Роджер Желязны                                           1
# Павел Корнев                                             1
