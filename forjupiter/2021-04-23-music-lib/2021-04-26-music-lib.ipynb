# %%
from alex_python_toolbox import google_drive
creds = google_drive.get_creds("client_secret.json",create_if_not_exist=True)
music_df = google_drive.download_df_from_google_sheets(creds,"1geXOAlLT7X0ig0r7jxbUPG-F_rnUyGKDnZr2pAeClak")

# %%
music_df.groupby("artist").agg({"filename":len}).sort_values(by="filename",ascending=False)
# Out:
#                   filename
# artist
#                      15007
# Роман Волков           257
# BIGBAG                 171
# Светлана Смелова        93
# Олег Воротилин          85
# Семен Мендельсон        36
# BadComedian             24
# #####                   21
# Олег Булдаков           21
# Father Thork             9
# Nigel Stanford           9
# Влад Копп                6
# Call Me Loop             1
# GAZIROVKA                1
# Nina Nesbitt             1
