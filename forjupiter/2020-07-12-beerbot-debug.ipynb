# %%
import pandas as pd
from datetime import datetime
from pytz import timezone
from pymongo import MongoClient

HEADERS= """Time Nanos
Time Millis
Level
Thread ID
Thread Name
Thread Priority
Formatted Message
Logger FQCN
Logger Name
Marker
Thrown Proxy
Source
Context Map
Context Stack""".split("\n")
TZ = "Asia/Tokyo"

with open("/Users/nailbiter/Documents/forgithub/ElDrinkoPubBot/secret.txt") as f:
    pwd = f.read().strip()

mongo_client = MongoClient(f"mongodb+srv://nailbiter:{pwd}@cluster0-ta3pc.gcp.mongodb.net/test?retryWrites=true&w=majority")
sensitive_data = [r["telegram"]["token"] for r in mongo_client.beerbot["_keyring"].find({})]

df = pd.read_csv("/Users/nailbiter/Documents/forgithub/ElDrinkoPubBot/.log/DevElDrinkoPubBot.csv",names=HEADERS
                )
df = df.replace(pwd,"***",regex=True)
for sd in sensitive_data:
    df = df.replace(sd,"***",regex=True)
df
# Out:
#      Time Nanos    Time Millis Level  Thread ID  \
# 0             0  1594638292031  INFO         14
# 1             0  1594638292033  INFO         14
# 2             0  1594638292660  INFO         14
# 3             0  1594638293566  INFO         14
# 4             0  1594638293604  INFO         14
# ..          ...            ...   ...        ...
# 213           0  1594638307714  INFO         25
# 214           0  1594638307714  INFO         25
# 215           0  1594638308193  INFO         25
# 216           0  1594638308663  INFO         25
# 217           0  1594638308663  INFO         25
#
#                                            Thread Name  Thread Priority  \
# 0    nl.insomnia247.nailbiter.eldrinkopubbot.App.ma...                5
# 1    nl.insomnia247.nailbiter.eldrinkopubbot.App.ma...                5
# 2    nl.insomnia247.nailbiter.eldrinkopubbot.App.ma...                5
# 3    nl.insomnia247.nailbiter.eldrinkopubbot.App.ma...                5
# 4    nl.insomnia247.nailbiter.eldrinkopubbot.App.ma...                5
# ..                                                 ...              ...
# 213                DevElDrinkoPubBot Telegram Executor                1
# 214                DevElDrinkoPubBot Telegram Executor                1
# 215                DevElDrinkoPubBot Telegram Executor                1
# 216                DevElDrinkoPubBot Telegram Executor                1
# 217                DevElDrinkoPubBot Telegram Executor                1
#
#                                      Formatted Message  \
# 0         COMMIT_DATA: `fix error message` (*0408b34*)
# 1                          BOT_NAME: DevElDrinkoPubBot
# 2                           botname: DevElDrinkoPubBot
# 3    _config: {"telegram":{"developerChatIds":["340...
# 4                 MiscUtils.GetResource(beerlist,.txt)
# ..                                                 ...
# 213  Уп-с!  Сталось, щось не те!\nДля виправлення, ...
# 214  sending Уп-с!  Сталось, щось не те!\nДля випра...
# 215  sending `(> 340880765 cannot find suitable tra...
# 216                               es(340880765): start
# 217                                om(340880765): null
#
#                                      Logger FQCN  \
# 0    org.apache.logging.log4j.spi.AbstractLogger
# 1    org.apache.logging.log4j.spi.AbstractLogger
# 2    org.apache.logging.log4j.spi.AbstractLogger
# 3    org.apache.logging.log4j.spi.AbstractLogger
# 4    org.apache.logging.log4j.spi.AbstractLogger
# ..                                           ...
# 213  org.apache.logging.log4j.spi.AbstractLogger
# 214  org.apache.logging.log4j.spi.AbstractLogger
# 215  org.apache.logging.log4j.spi.AbstractLogger
# 216  org.apache.logging.log4j.spi.AbstractLogger
# 217  org.apache.logging.log4j.spi.AbstractLogger
#
#                                            Logger Name  Marker  Thrown Proxy  \
# 0          nl.insomnia247.nailbiter.eldrinkopubbot.App     NaN           NaN
# 1          nl.insomnia247.nailbiter.eldrinkopubbot.App     NaN           NaN
# 2    nl.insomnia247.nailbiter.eldrinkopubbot.ElDrin...     NaN           NaN
# 3    nl.insomnia247.nailbiter.eldrinkopubbot.ElDrin...     NaN           NaN
# 4    nl.insomnia247.nailbiter.eldrinkopubbot.util.M...     NaN           NaN
# ..                                                 ...     ...           ...
# 213  nl.insomnia247.nailbiter.eldrinkopubbot.ElDrin...     NaN           NaN
# 214  nl.insomnia247.nailbiter.eldrinkopubbot.ElDrin...     NaN           NaN
# 215  nl.insomnia247.nailbiter.eldrinkopubbot.ElDrin...     NaN           NaN
# 216  nl.insomnia247.nailbiter.eldrinkopubbot.ElDrin...     NaN           NaN
# 217  nl.insomnia247.nailbiter.eldrinkopubbot.ElDrin...     NaN           NaN
#
#                                                 Source Context Map  \
# 0    nl.insomnia247.nailbiter.eldrinkopubbot.App.ma...          {}
# 1    nl.insomnia247.nailbiter.eldrinkopubbot.App.ma...          {}
# 2    nl.insomnia247.nailbiter.eldrinkopubbot.ElDrin...          {}
# 3    nl.insomnia247.nailbiter.eldrinkopubbot.ElDrin...          {}
# 4    nl.insomnia247.nailbiter.eldrinkopubbot.util.M...          {}
# ..                                                 ...         ...
# 213  nl.insomnia247.nailbiter.eldrinkopubbot.ElDrin...          {}
# 214  nl.insomnia247.nailbiter.eldrinkopubbot.ElDrin...          {}
# 215  nl.insomnia247.nailbiter.eldrinkopubbot.ElDrin...          {}
# 216  nl.insomnia247.nailbiter.eldrinkopubbot.ElDrin...          {}
# 217  nl.insomnia247.nailbiter.eldrinkopubbot.ElDrin...          {}
#
#     Context Stack
# 0              []
# 1              []
# 2              []
# 3              []
# 4              []
# ..            ...
# 213            []
# 214            []
# 215            []
# 216            []
# 217            []
#
# [218 rows x 14 columns]

# %%
df.loc[:,["Source"]].set_index("Source")
# Out:
# Empty DataFrame
# Columns: []
# Index: [nl.insomnia247.nailbiter.eldrinkopubbot.App.main(App.java:26), nl.insomnia247.nailbiter.eldrinkopubbot.App.main(App.java:27), nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoPubBot.<init>(ElDrinkoPubBot.java:216), nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoPubBot.<init>(ElDrinkoPubBot.java:233), nl.insomnia247.nailbiter.eldrinkopubbot.util.MiscUtils.GetResource(MiscUtils.java:49), nl.insomnia247.nailbiter.eldrinkopubbot.util.MiscUtils.GetResource(MiscUtils.java:58), nl.insomnia247.nailbiter.eldrinkopubbot.util.MiscUtils.GetResource(MiscUtils.java:49), nl.insomnia247.nailbiter.eldrinkopubbot.util.MiscUtils.GetResource(MiscUtils.java:58), nl.insomnia247.nailbiter.eldrinkopubbot.util.Cache.get(Cache.java:28), nl.insomnia247.nailbiter.eldrinkopubbot.util.Cache.get(Cache.java:25), nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoStateMachine.PreloadImages(ElDrinkoStateMachine.java:67), nl.insomnia247.nailbiter.eldrinkopubbot.util.DownloadCache.get(DownloadCache.java:35), nl.insomnia247.nailbiter.eldrinkopubbot.util.DownloadCache.get(DownloadCache.java:51), nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoStateMachine.PreloadImages(ElDrinkoStateMachine.java:69), nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoStateMachine.PreloadImages(ElDrinkoStateMachine.java:67), nl.insomnia247.nailbiter.eldrinkopubbot.util.DownloadCache.get(DownloadCache.java:35), nl.insomnia247.nailbiter.eldrinkopubbot.util.DownloadCache.get(DownloadCache.java:51), nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoStateMachine.PreloadImages(ElDrinkoStateMachine.java:69), nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoStateMachine.PreloadImages(ElDrinkoStateMachine.java:67), nl.insomnia247.nailbiter.eldrinkopubbot.util.DownloadCache.get(DownloadCache.java:35), nl.insomnia247.nailbiter.eldrinkopubbot.util.DownloadCache.get(DownloadCache.java:51), nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoStateMachine.PreloadImages(ElDrinkoStateMachine.java:69), nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoStateMachine.PreloadImages(ElDrinkoStateMachine.java:67), nl.insomnia247.nailbiter.eldrinkopubbot.util.DownloadCache.get(DownloadCache.java:35), nl.insomnia247.nailbiter.eldrinkopubbot.util.DownloadCache.get(DownloadCache.java:51), nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoStateMachine.PreloadImages(ElDrinkoStateMachine.java:69), nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoStateMachine.PreloadImages(ElDrinkoStateMachine.java:67), nl.insomnia247.nailbiter.eldrinkopubbot.util.DownloadCache.get(DownloadCache.java:35), nl.insomnia247.nailbiter.eldrinkopubbot.util.DownloadCache.get(DownloadCache.java:51), nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoStateMachine.PreloadImages(ElDrinkoStateMachine.java:69), nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoStateMachine.PreloadImages(ElDrinkoStateMachine.java:67), nl.insomnia247.nailbiter.eldrinkopubbot.util.DownloadCache.get(DownloadCache.java:35), nl.insomnia247.nailbiter.eldrinkopubbot.util.DownloadCache.get(DownloadCache.java:51), nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoStateMachine.PreloadImages(ElDrinkoStateMachine.java:69), nl.insomnia247.nailbiter.eldrinkopubbot.util.MiscUtils.GetResource(MiscUtils.java:49), nl.insomnia247.nailbiter.eldrinkopubbot.util.MiscUtils.GetResource(MiscUtils.java:58), nl.insomnia247.nailbiter.eldrinkopubbot.util.MiscUtils.GetResource(MiscUtils.java:49), nl.insomnia247.nailbiter.eldrinkopubbot.util.MiscUtils.GetResource(MiscUtils.java:58), nl.insomnia247.nailbiter.eldrinkopubbot.util.MiscUtils.GetResource(MiscUtils.java:49), nl.insomnia247.nailbiter.eldrinkopubbot.util.MiscUtils.GetResource(MiscUtils.java:58), nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoConditionInflator.apply(ElDrinkoConditionInflator.java:80), nl.insomnia247.nailbiter.eldrinkopubbot.state_machine.StateMachine.inflateTransitionsFromJSON(StateMachine.java:38), nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoConditionInflator.apply(ElDrinkoConditionInflator.java:80), nl.insomnia247.nailbiter.eldr ...
#
# [218 rows x 0 columns]

# %%
import pandas as pd
from datetime import datetime
from IPython.core.display import HTML

def condition(ud,s):
    for p in ["ss","im","om","es"]:
        if s.startswith(f"{p}({ud})"):
            return True
    return False

_df = df[[x=="nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoPubBot" for x in df["Logger Name"]]].loc[:,["Time Millis","Formatted Message"]]
_df = pd.DataFrame([
    {
        "date":datetime.fromtimestamp(r["Time Millis"]/1000), 
        "prefix":r["Formatted Message"].split(":",maxsplit=2)[0],
        "msg":r["Formatted Message"].split(":",maxsplit=2)[1]
    } 
    for r 
    in _df.to_dict(orient="records")
    if condition("340880765",r["Formatted Message"])
]).set_index("date")
HTML(_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>prefix</th>
#       <th>msg</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2020-07-12 13:58:49.152</th>
#       <td>ss(340880765)</td>
#       <td>_</td>
#     </tr>
#     <tr>
#       <th>2020-07-12 13:58:49.152</th>
#       <td>im(340880765)</td>
#       <td>(TelegramInputMessage(/start),{})</td>
#     </tr>
#     <tr>
#       <th>2020-07-12 13:58:49.283</th>
#       <td>es(340880765)</td>
#       <td>start</td>
#     </tr>
#     <tr>
#       <th>2020-07-12 13:58:49.283</th>
#       <td>om(340880765)</td>
#       <td>([TelegramOutputMessage(Вітаємо!\n),TelegramKeyboard(Сьогодні ми пропонуємо</td>
#     </tr>
#     <tr>
#       <th>2020-07-12 13:58:59.361</th>
#       <td>ss(340880765)</td>
#       <td>start</td>
#     </tr>
#     <tr>
#       <th>2020-07-12 13:58:59.362</th>
#       <td>im(340880765)</td>
#       <td>(TelegramKeyboardAnswer(0),{})</td>
#     </tr>
#     <tr>
#       <th>2020-07-12 13:58:59.387</th>
#       <td>es(340880765)</td>
#       <td>choose_product_to_make_order</td>
#     </tr>
#     <tr>
#       <th>2020-07-12 13:58:59.388</th>
#       <td>om(340880765)</td>
#       <td>(TelegramKeyboard(Покласти в кошик\n,[IPA - 77грн., Milk Stout - 69грн., Wizen - 54грн., Pilsner - 54грн., Pale Ale - 57грн., Mars - 72грн.]),{})</td>
#     </tr>
#   </tbody>
# </table>

# %%
from IPython.core.display import HTML

_df = df[[x=="nl.insomnia247.nailbiter.eldrinkopubbot.ElDrinkoPubBot" for x in df["Logger Name"]]].loc[:,["Time Millis","Formatted Message"]]
HTML(_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Time Millis</th>
#       <th>Formatted Message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>1594529921876</td>
#       <td>botname: DevElDrinkoPubBot</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1594529922970</td>
#       <td>_config: {"telegram":{"developerChatIds":["340880765"],"salesmanChatIds":["340880765"],"token":"***"},"_id":{"$oid":"5ec9e2b211a1c968d67fadd0"},"id":"DevElDrinkoPubBot","mongodb":{"state_machine_states":"dev_state_machine_states","data":"dev_data","logs":"dev_logs"}}\n</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>1594529927166</td>
#       <td>edsm: "choose_phone_number" -&gt; "choose_phone_number"\n"start" -&gt; "start"\n"choose_address" -&gt; "choose_phone_number"\n"idle" -&gt; "start"\n"choose_product_to_make_order" -&gt; "choose_amount"\n"send" -&gt; "start"\n"send" -&gt; "idle"\n"confirm" -&gt; "start"\n"choose_phone_number" -&gt; "choose_payment"\n"edit_address" -&gt; "start"\n"delete" -&gt; "start"\n"choose_amount" -&gt; "confirm"\n"confirm" -&gt; "choose_address"\n"start" -&gt; "choose_product_to_see_description"\n"choose_product_to_see_description" -&gt; "start"\n"start" -&gt; "choose_product_to_make_order"\n"choose_product_to_make_order" -&gt; "start"\n"choose_payment" -&gt; "start"\n"choose_address" -&gt; "start"\n"confirm" -&gt; "choose_product_to_make_order"\n"choose_phone_number" -&gt; "start"\n"_" -&gt; "start"\n"send" -&gt; "edit_address"\n"edit_address" -&gt; "send"\n"choose_payment" -&gt; "send"\n"send" -&gt; "choose_payment"\n"confirm" -&gt; "delete"\n"delete" -&gt; "confirm"\n"choose_amount" -&gt; "start"\n\n</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>1594529927167</td>
#       <td>sending `(&gt; updated! now at `beerbot milestone (28/39=71.79%)` (*51ad367*) &lt;)` to 340880765\n</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>1594529929029</td>
#       <td>start CreateInputMessage</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>1594529929031</td>
#       <td>here: dev_state_machine_states</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>1594529929105</td>
#       <td>doc: null</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>1594529929152</td>
#       <td>ss(340880765): _</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>1594529929152</td>
#       <td>im(340880765): (TelegramInputMessage(/start),{})</td>
#     </tr>
#     <tr>
#       <th>137</th>
#       <td>1594529929283</td>
#       <td>es(340880765): start</td>
#     </tr>
#     <tr>
#       <th>138</th>
#       <td>1594529929283</td>
#       <td>om(340880765): ([TelegramOutputMessage(Вітаємо!\n),TelegramKeyboard(Сьогодні ми пропонуємо:\n1. IPA (77.00 грн/л)\n2. Milk Stout (69.00 грн/л)\n3. Wizen (54.00 грн/л)\n4. Pilsner (54.00 грн/л)\n5. Pale Ale (57.00 грн/л)\n6. Mars (72.00 грн/л)\n,[Замовити, Дивитись описи]),],{})</td>
#     </tr>
#     <tr>
#       <th>139</th>
#       <td>1594529929806</td>
#       <td>after execute(TelegramOutputMessage(Вітаємо!\n)) as 1741</td>
#     </tr>
#     <tr>
#       <th>140</th>
#       <td>1594529930223</td>
#       <td>after execute(TelegramKeyboard(Сьогодні ми пропонуємо:\n1. IPA (77.00 грн/л)\n2. Milk Stout (69.00 грн/л)\n3. Wizen (54.00 грн/л)\n4. Pilsner (54.00 грн/л)\n5. Pale Ale (57.00 грн/л)\n6. Mars (72.00 грн/л)\n,[Замовити, Дивитись описи])) as 1742</td>
#     </tr>
#     <tr>
#       <th>141</th>
#       <td>1594529938434</td>
#       <td>start CreateInputMessage</td>
#     </tr>
#     <tr>
#       <th>142</th>
#       <td>1594529938435</td>
#       <td>inline markup: [[InlineKeyboardButton{text='Замовити', url='null', callbackData='0', callbackGame=null, switchInlineQuery='null', switchInlineQueryCurrentChat='null', pay=null, loginUrl=null}, InlineKeyboardButton{text='Дивитись описи', url='null', callbackData='1', callbackGame=null, switchInlineQuery='null', switchInlineQueryCurrentChat='null', pay=null, loginUrl=null}]]\n</td>
#     </tr>
#     <tr>
#       <th>143</th>
#       <td>1594529939236</td>
#       <td>call_data: 0\n</td>
#     </tr>
#     <tr>
#       <th>144</th>
#       <td>1594529939237</td>
#       <td>TelegramKeyboardAnswer(0) to 1742</td>
#     </tr>
#     <tr>
#       <th>145</th>
#       <td>1594529939238</td>
#       <td>here: dev_state_machine_states</td>
#     </tr>
#     <tr>
#       <th>146</th>
#       <td>1594529939295</td>
#       <td>doc: Document{{_id=5f0a9889ee365246d54159de, id=340880765, state=start}}</td>
#     </tr>
#     <tr>
#       <th>148</th>
#       <td>1594529939361</td>
#       <td>ss(340880765): start</td>
#     </tr>
#     <tr>
#       <th>149</th>
#       <td>1594529939362</td>
#       <td>im(340880765): (TelegramKeyboardAnswer(0),{})</td>
#     </tr>
#     <tr>
#       <th>197</th>
#       <td>1594529939387</td>
#       <td>es(340880765): choose_product_to_make_order</td>
#     </tr>
#     <tr>
#       <th>198</th>
#       <td>1594529939388</td>
#       <td>om(340880765): (TelegramKeyboard(Покласти в кошик\n,[IPA - 77грн., Milk Stout - 69грн., Wizen - 54грн., Pilsner - 54грн., Pale Ale - 57грн., Mars - 72грн.]),{})</td>
#     </tr>
#     <tr>
#       <th>199</th>
#       <td>1594529939888</td>
#       <td>after execute(TelegramKeyboard(Покласти в кошик\n,[IPA - 77грн., Milk Stout - 69грн., Wizen - 54грн., Pilsner - 54грн., Pale Ale - 57грн., Mars - 72грн.])) as 1744</td>
#     </tr>
#   </tbody>
# </table>
