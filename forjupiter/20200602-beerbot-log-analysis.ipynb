# %%
import pandas as pd
# import re

with open("/Users/nailbiter/Documents/forgithub/ElDrinkoPubBot/secret.txt") as f:
    pwd = f.read().strip()
df = pd.read_csv("/Users/nailbiter/Documents/forgithub/ElDrinkoPubBot/.log/DevElDrinkoPubBot.csv").replace(pwd,"***",regex=True)
df
# Out:
#    0  1591056156407  INFO  14  \
# 0  0  1591056156410  INFO  14
# 1  0  1591056158110  INFO  14
# 2  0  1591056158159  INFO  14
#
#   nl.insomnia247.nailbiter.eldrinkopubbot.App.main()  5  \
# 0  nl.insomnia247.nailbiter.eldrinkopubbot.App.ma...  5
# 1  nl.insomnia247.nailbiter.eldrinkopubbot.App.ma...  5
# 2  nl.insomnia247.nailbiter.eldrinkopubbot.App.ma...  5
#
#   args(2): [`Merge pull request #25 from nailbiter/staging` (*5cbdd8f*),DevElDrinkoPubBot]  \
# 0                                        secret: ***
# 1  _config: {"telegram":{"masterChatIds":["340880...
# 2  sending updated! now at `Merge pull request #2...
#
#    org.apache.logging.log4j.spi.AbstractLogger  \
# 0  org.apache.logging.log4j.spi.AbstractLogger
# 1  org.apache.logging.log4j.spi.AbstractLogger
# 2  org.apache.logging.log4j.spi.AbstractLogger
#
#          nl.insomnia247.nailbiter.eldrinkopubbot.App  Unnamed: 9  Unnamed: 10  \
# 0        nl.insomnia247.nailbiter.eldrinkopubbot.App         NaN          NaN
# ...
