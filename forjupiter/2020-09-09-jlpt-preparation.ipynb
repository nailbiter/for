# %%
from os import walk
from os.path import join
import pandas as pd

# for root, dirs, files in walk("/Users/nailbiter/Documents/duolingo/"):
#     for name in files:
#         print(join(root,name))
decks = pd.read_csv("/Users/nailbiter/Documents/duolingo/decks.csv")
decks
# Out:
#                                 name  \
# 0                  N2 tango 2500 (9)
# 1                  N2 tango 2500 (8)
# 2                  N2 tango 2500 (8)
# 3                  N2 tango 2500 (7)
# 4                  N2 tango 2500 (6)
# 5                  N2 tango 2500 (5)
# 6                  N2 tango 2500 (4)
# 7                  N2 tango 2500 (3)
# 8                  N2 tango 2500 (2)
# 9                  N2 tango 2500 (1)
# 10                    Cody Chrysalis
# 11                     Candice TOEIC
# 12          Open Letter to Brazil #8
# 13          Open Letter to Brazil #7
# 14  dann denn wenn weil dass deshalb
# 15                        Schwarz #1
# 16          Open Letter to Brazil #6
# 17          Open Letter to Brazil #5
# 18          Open Letter to Brazil #4
# 19          open letter to Brazil #4
# 20                        Schwarz #2
# 21          Open Letter to Brazil #3
# 22          Open Letter to Brazil #3
# 23                        Goethe L12
# 24          Open Letter to Brazil #2
# 25                        Goethe L11
# 26                        Goethe L10
# 27          Open Letter to Brazil #1
# 28                         Goethe L9
# 29                         Goethe L8
# 30                         Goethe L7
# 31                         Goethe L6
# 32                         Goethe L4
# 33                    german perfect
# 34         German position particles
# 35                Wort fur Wort (XI)
# 36                 wort fur wort (X)
# 37                  german sentences
# 38                Wort fur Wort (IX)
# 39                      german cases
# 40             Pluralization, part 1
# 41             Pluralization, part 2
# 42              Wort fur Wort (VIII)
# 43           Mary SAT English (tech)
# 44       Mary SAT English (non-tech)
# 45                        Basic trig
# 46               Wort für Wort (VII)
# 47                Wort für Wort (VI)
# 48                          pronouns
# 49                    German Genders
# 50                 Wort für Wort (V)
# 51                Wort für Wort (IV)
# 52               Wort für wort (III)
# 53                Wort für Wort (II)
# 54                 Wort für wort (I)
# 55                          Japanese
#
#                                           description  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                       N2 words 2500
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                  Restlos Glücklich
# 26                                                NaN
# 27                                                NaN
# 28                                               Cars
# 29                  Hoffentlich ist es nicht das Herz
# 30                                                NaN
# 31                                                NaN
# 32                                            Packing
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                          German vocabulary, part 7
# 47                          German vocabulary, part 6
# 48                                                NaN
# 49                                                NaN
# 50                          german vocabulary, part 5
# 51                                  German vocabulary
# 52                          german vocabulary, part 3
# 53                          german vocabulary, part 2
# 54                          german vocabulary, part 1
# 55  Japanese words taken from texts in トピック日本語総合演習...
#
#                                            coverImage  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37  https://s3.amazonaws.com/tinycards/image/16cb6...
# 38                                                NaN
# 39                                                NaN
# 40  https://s3.amazonaws.com/tinycards/image/16cb6...
# 41  https://s3.amazonaws.com/tinycards/image/16cb6...
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46  https://s3.amazonaws.com/tinycards/image/56a85...
# 47  https://s3.amazonaws.com/tinycards/image/2ba76...
# 48  https://s3.amazonaws.com/tinycards/image/16cb6...
# 49  https://s3.amazonaws.com/tinycards/image/16cb6...
# 50  https://s3.amazonaws.com/tinycards/image/fc7df...
# 51  https://s3.amazonaws.com/tinycards/image/1c27b...
# 52  https://s3.amazonaws.com/tinycards/image/4513f...
# 53  https://s3.amazonaws.com/tinycards/image/08be7...
# 54  https://s3.amazonaws.com/tinycards/image/4af69...
# 55  https://s3.amazonaws.com/tinycards/image/cb772...
#
#                                                 cards  \
# 0   ### Card 1\nFront\n* しかも\n\nBack\n* moreover\n...
# 1   ### Card 1\nFront\n* つらい\n\nBack\n* painful, d...
# 2   ### Card 1\nFront\n* 目撃\n\nBack\n* witness\n* ...
# 3   ### Card 1\nFront\n* 定期的な\n\nBack\n* periodic\...
# 4   ### Card 1\nFront\n* 本格的な\n\nBack\n* serious\n...
# 5   ### Card 1\nFront\n* 組む\n\nBack\n* to join\n* ...
# 6   ### Card 1\nFront\n* 高等な\n\nBack\n* superior\n...
# 7   ### Card 1\nFront\n* 可燃ゴミ\n\nBack\n* burnable ...
# 8   ### Card 1\nFront\n* 残高\n\nBack\n* balance\n* ...
# 9   ### Card 1\nFront\n* 一家\n\nBack\n* family\n* い...
# 10  ### Card 1\nFront\n* type\n\nBack\n* 型\n\n### ...
# 11  ### Card 1\nFront\n* reception\n\nBack\n* 歓迎会\...
# 12  ### Card 1\nFront\n* To contribute\n\nBack\n* ...
# 13  ### Card 1\nFront\n* extreme\n\nBack\n* ярко в...
# 14  ### Card 1\nFront\n* if\n\nBack\n* Wenn ich im...
# 15  ### Card 1\nFront\n* bummeln\n\nBack\n* to wal...
# 16  ### Card 1\nFront\n* official\n\nBack\n* чинов...
# 17  ### Card 1\nFront\n* these\n\nBack\n* эти\n\n#...
# 18  ### Card 1\nFront\n* social consciousness\n\nB...
# 19  ### Card 1\nFront\n* expensive\n\nBack\n* доро...
# 20  ### Card 1\nFront\n* Vokal\n\nBack\n* vowel\n\...
# 21  ### Card 1\nFront\n* to be sure\n\nBack\n* быт...
# 22  ### Card 1\nFront\n* upon mentioning it\n\nBac...
# 23  ### Card 1\nFront\n* die Gewohnheit\n\nBack\n*...
# 24  ### Card 1\nFront\n* screwed up\n\nBack\n* исп...
# 25  ### Card 1\nFront\n* der Briefumschlag\n\nBack...
# 26  ### Card 1\nFront\n* gut durch\n\nBack\n* well...
# 27  ### Card 1\nFront\n* finally\n\nBack\n* наконе...
# 28  ### Card 1\nFront\n* bauen\n\nBack\n* produce,...
# 29  ### Card 1\nFront\n* der Herzinfarkt\n\nBack\n...
# 30  ### Card 1\nFront\n* ![image](https://d9np3dj8...
# 31  ### Card 1\nFront\n* Eintritt\n\nBack\n* ![ima...
# 32  ### Card 1\nFront\n* Tüte\n\nBack\n* ![image](...
# 33  ### Card 1\nFront\n* arbeiten\n\nBack\n* hat g...
# 34  ### Card 1\nFront\n* ![image](https://d9np3dj8...
# 35  ### Card 1\nFront\n* den Rekord brechen (i-a-o...
# 36  ### Card 1\nFront\n* die Startbahn (-en)\n\nBa...
# 37  ### Card 1\nFront\n* The Mercedes is very fast...
# 38  ### Card 1\nFront\n* ich verbrachte 2 Wochen i...
# 39  ### Card 1\nFront\n* bis (until) ...\n\nBack\n...
# 40  ### Card 1\nFront\n* M. nouns  of 1 syllable; ...
# 41  ### Card 1\nFront\n* das Auge\n\nBack\n* -n\n\...
# 42  ### Card 1\nFront\n* am schwersten betroffen s...
# 43  ### Card 1\nFront\n* acute\n\nBack\n* острый (...
# 44  People with a private link       en     True  2018-03-04 15:54:07
# 45  People with a private link       en    False  2018-02-14 00:45:55
# 46  People with a private link       en    False  2018-02-04 11:13:25
# 47  People with a private link       en    False  2018-01-25 02:45:25
# 48                     Only me       en    False  2018-02-01 16:59:32
# 49                     Only me       en    False  2018-02-01 09:14:50
# 50  People with a private link       en    False  2018-01-16 08:46:13
# 51  People with a private link       en    False  2017-12-01 07:15:08
# 52  People with a private link       en    False  2017-11-20 06:12:10
# 53  People with a private link       en    False  2017-11-10 02:58:42
# 54  People with a private link       en    False  2017-10-25 00:56:32
# 55                    Everyone       en    False  2016-10-01 13:30:27
#
#               updatedAt
# 0   2020-05-08 05:50:53
# 1   2020-05-08 05:36:44
# 2   2020-05-07 13:50:35
# 3   2020-05-06 13:24:44
# 4   2020-05-06 08:14:25
# 5   2020-05-06 05:53:02
# 6   2020-04-28 14:36:16
# 7   2020-05-14 14:07:45
# 8   2020-05-10 03:51:27
# 9   2020-03-27 01:57:37
# 10  2019-11-11 14:24:58
# 11  2019-01-13 01:42:33
# 12  2019-01-10 10:22:52
# 13  2018-12-11 14:13:08
# 14  2018-11-27 12:05:54
# 15  2018-11-19 05:55:11
# 16  2018-11-27 08:04:27
# 17  2018-11-06 08:15:22
# 18  2018-10-30 02:28:36
# 19  2018-10-22 06:20:30
# 20  2018-10-18 09:46:49
# 21  2018-10-03 06:59:26
# 22  2018-09-25 07:49:52
# 23  2018-09-20 12:19:32
# 24  2018-09-18 07:36:27
# 25  2018-09-13 03:26:08
# 26  2018-09-13 02:34:02
# 27  2018-09-09 14:26:35
# 28  2018-09-11 01:15:04
# 29  2018-09-04 03:42:07
# 30  2018-09-04 00:46:16
# 31  2018-08-29 14:53:05
# 32  2018-08-27 22:39:17
# 33  2018-08-09 09:13:42
# 34  2018-08-08 12:35:24
# 35  2018-04-24 01:05:16
# 36  2018-04-12 12:01:18
# 37  2018-04-02 12:47:08
# 38  2018-04-01 07:59:45
# 39  2018-03-23 00:25:24
# 40  2018-03-23 10:26:31
# 41  2018-03-20 13:52:52
# 42  2018-03-18 11:05:25
# 43  2018-03-07 03:26:29
# 44  2018-03-07 03:26:14
# 45  2018-02-14 07:48:25
# 46  2018-03-01 03:50:18
# 47  2018-02-04 06:48:32
# 48  2018-02-07 04:43:21
# 49  2018-02-01 13:36:16
# 50  2018-01-24 12:39:10
# 51  2018-01-21 09:37:35
# 52  2018-01-21 09:43:10
# 53  2018-01-21 09:44:08
# 54  2018-01-21 09:39:50
# 55  2017-09-08 01:48:54

# %%
from functools import reduce
from re import match

class Card:
    def __init__(self,lines):
        self._lines = lines
        front_i, back_i = lines.index("Front"),lines.index("Back")
        self._front = [s[2:] for s in lines[front_i+1:back_i]]
        self._back = [s[2:
                       ] for s in lines[back_i+1:]]
    def __str__(self):
        _d = {"front":self._front,"back":self._back}
        return f"Card({_d})"
    def to_dict(self):
        return {"front":self._front,"back":self._back}
class Deck:
    def __init__(self,s,name):
        lines = s.split("\n")
        def _reducer(val,elt):
            if match(r"### Card \d+",elt) is not None:
                val["res"].append(val["buf"])
                val["buf"] = []
            else:
                val["buf"].append(elt)
            return val
        _deck = reduce(_reducer, lines, {"buf":[],"res":[]})
        if _deck["buf"]:
            _deck["res"].append(_deck["buf"])
        _deck["res"] = [Card([aa for aa in a if aa]) for a in _deck["res"] if a]
        self._deck = _deck["res"]
        self._name = name
    def get_name(self):
        return self._name
    def get_size(self):
        return len(self._deck)
    def __str__(self):
        _s = ", ".join(str(c) for c in self._deck)
        return f"Deck(name={self._name},[{_s}])"
    def to_dict(self):
        return {self._name:[c.to_dict() for c in self._deck]}
        

decks_df = pd.DataFrame({"cards":[Deck(s=cards,name=name) for cards,name in zip(decks["cards"],decks["name"])]})

# %%
# from pymongo import MongoClient
# from tqdm import tqdm

# mongo_client = MongoClient()
# coll = mongo_client.alex_flashcards.cards

# _deck = [d.to_dict() for d in decks_df["cards"]]
# for d in tqdm(_deck):
#     k,v = list(d.items())[0]
#     for c in v:
#         doc = {"tags":[k,"tinycards"],**c}
#         assert len(doc["front"])==1
#         doc["front"] = doc["front"][0]
#         coll.insert_one(doc)
# Out:
# 100%|██████████| 56/56 [00:01<00:00, 55.75it/s]

# %%
_df = decks_df[["N2 tango" in d.get_name() for d in decks_df["cards"]]].copy()
_df["name"] = [d.get_name() for d in _df["cards"]]
_df["size"] = [d.get_size() for d in _df["cards"]]
num_of_cards = sum(_df["size"])
print(f"num_of_cards: {num_of_cards}")
# _df
# Out:
# num_of_cards: 1364

# %%
_df = schedule_df.groupby("book").sum()
print(_df)
sum(_df["words"])
# Out:
#                page_count  words
# book
# None                    0     38
# n2 in 20 days         165    476
# n2 listening          102    289
# n2 reading            196    561
# 1364

# %%
from datetime import datetime, timedelta
from math import ceil
from copy import deepcopy
# from math impo

PAGE_COUNTS = {
    "n2 listening":102,
    "n2 reading":196,
    "n2 in 20 days":165,
}
MOCK_EXAMS = 1
TEST_DATE = datetime(2020,12,6)

start_date = datetime.today()+timedelta(days=2)
days_remain = (TEST_DATE-start_date).days
average_pages_per_day = ceil(sum(PAGE_COUNTS.values())/days_remain)
average_words_per_day = ceil(num_of_cards/days_remain)

records = []
_noc = num_of_cards
_ski = 0
_pc = deepcopy(PAGE_COUNTS)
_keys = [*list(_pc),"",""]
while sum(_pc.values())>0 or _noc>0:
    if _pc.get(_keys[_ski],0)==0:
        _ski += 1
    if _ski<len(_pc):
        norm = min(_pc.get(list(_pc)[_ski],0),average_pages_per_day)
        _pc[list(_pc)[_ski]] -= norm
    else:
        norm = 0
    norm_words = min(average_words_per_day,_noc)
    _noc -= norm_words
    records.append({"book":list(_pc)[_ski] if _ski<len(_pc) else "None", "page_count":norm,"date":start_date.date(),"words":norm_words})
    start_date += timedelta(days=1)

schedule_df = pd.DataFrame(records)
schedule_df
# Out:
#              book  page_count        date  words
# 0    n2 listening           6  2020-09-12     17
# 1    n2 listening           6  2020-09-13     17
# 2    n2 listening           6  2020-09-14     17
# 3    n2 listening           6  2020-09-15     17
# 4    n2 listening           6  2020-09-16     17
# ..            ...         ...         ...    ...
# 76  n2 in 20 days           6  2020-11-27     17
# 77  n2 in 20 days           3  2020-11-28     17
# 78           None           0  2020-11-29     17
# 79           None           0  2020-11-30     17
# 80           None           0  2020-12-01      4
#
# [81 rows x 4 columns]
